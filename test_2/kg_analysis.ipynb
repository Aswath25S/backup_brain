# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

from langchain_openai import ChatOpenAI
from langchain_text_splitters import TokenTextSplitter
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
main_path = "/home/aswath/Projects/deep_learning/backup_brain/test_2/"

# %% [markdown]
# ### Demonstration of Knowledge Graph Creation

# %%
input_path = main_path + "input/outsiders.txt"

# %%
with open(input_path, 'r') as file:
    content = file.read()

text_splitter = TokenTextSplitter(chunk_size=2000, chunk_overlap=100)
texts = text_splitter.split_text(content)

# %%
prompt_template = """
-Goal-
Given a text document about unconventional CEOs and their business strategies, identify all significant entities and relationships related to management philosophy, operational models, and organizational behavior. Also identify communities or clusters of similarly acting individuals or organizations if applicable.

-Steps-
1. Identify all entities. For each identified entity, extract the following information:
- entity_name: Name of the entity, capitalized
- entity_type: One of the following types: [CEO, business strategy, capital allocation approach, acquisition strategy, management style, organizational structure, performance metric, leadership trait, company, investment philosophy, decentralization approach, financial policy, operational efficiency, cultural value, peer group]
- entity_description: Comprehensive description of the entity’s attributes, behaviors, or significance
Format each entity as ("entity"{{tuple_delimiter}}<entity_name>{{tuple_delimiter}}<entity_type>{{tuple_delimiter}}<entity_description>)

2. From the entities identified in step 1, identify all pairs of (source_entity, target_entity) that are *clearly related* to each other.
For each pair of related entities, extract the following information:
- source_entity: name of the source entity, as identified in step 1
- target_entity: name of the target entity, as identified in step 1
- relationship_description: explanation as to why you think the source entity and the target entity are related to each other
- relationship_strength: an integer score between 1 to 10, indicating strength of the relationship between the source entity and target entity
Format each relationship as ("relationship"{{tuple_delimiter}}<source_entity>{{tuple_delimiter}}<target_entity>{{tuple_delimiter}}<relationship_description>{{tuple_delimiter}}<relationship_strength>)

3. Return output in English as a single list of all the entities and relationships identified in steps 1 and 2. Use **{{record_delimiter}}** as the list delimiter.

4. If you have to translate into English, just translate the descriptions, nothing else!

5. When finished, output {{completion_delimiter}}.

-Examples-
######################

entity_types: [CEO, business strategy, capital allocation approach, acquisition strategy, management style, organizational structure, performance metric, leadership trait, company, investment philosophy, decentralization approach, financial policy, operational efficiency, cultural value, peer group]
text: {input_text}
######################
output:
"""

# %%
llm = ChatOpenAI(temperature=0.0, model="gpt-4o", api_key= "dummy_val")

prompt = ChatPromptTemplate.from_template(prompt_template)
chain = prompt | llm | StrOutputParser()

# %%
response = chain.invoke({"input_text": content[:10000]})

# %%
print(response)
# Out:
# ("entity" | "John Templeton" | "CEO" | "John Templeton is known for his quote about producing superior performance by doing something different, highlighting his unconventional approach to business leadership.") **{record_delimiter}** ("entity" | "Henry Singleton" | "CEO" | "Henry Singleton was a CEO known for his unconventional management style and superior market performance compared to peers like Jack Welch.") **{record_delimiter}** ("entity" | "Jack Welch" | "CEO" | "Jack Welch is a well-known CEO, often portrayed as a charismatic, action-oriented leader, and a benchmark for market performance.") **{record_delimiter}** ("entity" | "Warren Buffett" | "CEO" | "Warren Buffett is a renowned CEO who identified the 'institutional imperative' as a force that compels CEOs to imitate their peers.") **{record_delimiter}** ("entity" | "Teledyne" | "company" | "Teledyne is a company known for its exceptional market performance under unconventional leadership.") **{record_delimiter}** ("entity" | "Singletonville" | "peer group" | "Singletonville refers to a group of CEOs who share unconventional management styles and superior performance.") **{record_delimiter}** ("entity" | "Billy Beane" | "CEO" | "Billy Beane is known for his unconventional, analytical approach to managing the Oakland A's baseball team, leading to exceptional performance.") **{record_delimiter}** ("entity" | "Oakland A's" | "company" | "The Oakland A's is a baseball team managed by Billy Beane, known for its success despite financial constraints.") **{record_delimiter}** ("entity" | "institutional imperative" | "management philosophy" | "The institutional imperative is a concept identified by Warren Buffett, describing the tendency of CEOs to imitate their peers.") **{record_delimiter}** ("entity" | "decentralization approach" | "decentralization approach" | "A management approach where organizations are run in a highly decentralized manner, allowing for independent decision-making.") **{record_delimiter}** ("entity" | "cash flow–based metrics" | "performance metric" | "Unusual financial metrics focused on cash flow, used by unconventional CEOs to measure performance.") **{record_delimiter}** ("entity" | "General Cinema's Dick Smith" | "CEO" | "Dick Smith was a CEO known for his patient investment strategy, waiting for compelling opportunities.") **{record_delimiter}** ("relationship" | "John Templeton" | "Henry Singleton" | "Both are noted for their unconventional approaches to achieving superior performance." | 7) **{record_delimiter}** ("relationship" | "Henry Singleton" | "Singletonville" | "Henry Singleton is a part of the group of unconventional CEOs referred to as Singletonville." | 8) **{record_delimiter}** ("relationship" | "Jack Welch" | "Henry Singleton" | "Henry Singleton's performance was compared to Jack Welch's, highlighting Singleton's superior market performance." | 6) **{record_delimiter}** ("relationship" | "Warren Buffett" | "institutional imperative" | "Warren Buffett identified the institutional imperative as a key concept in CEO behavior." | 9) **{record_delimiter}** ("relationship" | "Billy Beane" | "Oakland A's" | "Billy Beane's management of the Oakland A's is a prime example of his unconventional approach." | 10) **{record_delimiter}** ("relationship" | "decentralization approach" | "Singletonville" | "The CEOs in Singletonville employed a highly decentralized approach in their management." | 8) **{record_delimiter}** ("relationship" | "cash flow–based metrics" | "Singletonville" | "The CEOs in Singletonville used cash flow–based metrics to measure performance." | 8) **{record_delimiter}** ("relationship" | "General Cinema's Dick Smith" | "Singletonville" | "Dick Smith's patient investment strategy aligns with the unconventional approaches of Singletonville CEOs." | 7) **{completion_delimiter}**

# %% [markdown]
# ### Analysing Created Knowledge Graph

# %%
entities_path = main_path + "output/entities.parquet"
communities_path = main_path + "output/communities.parquet"
community_reports_path = main_path + "output/community_reports.parquet"
documents_path = main_path + "output/documents.parquet"
relationships_path = "output/relationships.parquet"

entity_df = pd.read_parquet(entities_path)
community_df = pd.read_parquet(communities_path)
community_report_df = pd.read_parquet(community_reports_path)
documents_df = pd.read_parquet(documents_path)
relationships_df = pd.read_parquet(relationships_path)

# %% [markdown]
# ### Entity

# %%
entity_df.head()
# Out:
#                                      id  human_readable_id         title  \
# 0  f9953914-7b91-481e-a894-edf6606cb1a2                  0       STIRITZ
# 1  d7fab43d-fd59-46e6-b719-eedf2bce399b                  1  RAND ARASKOG
# 2  18a7b985-3ec2-4e79-9a2a-f18bc7662328                  2   PAT MULCAHY
# 3  eaa3b8ee-dd6f-4408-af25-a9e0f5813eab                  3       RALSTON
# 4  655f0026-f1e0-4041-93a8-fc419dd56ec2                  4     ENERGIZER
#
#            type                                        description  \
# 0        PERSON  Stiritz is a business executive known for his ...
# 1        PERSON  Rand Araskog was the chairman of ITT, from who...
# 2        PERSON  Pat Mulcahy is a protégé of Stiritz who later ...
# 3  ORGANIZATION  Ralston is a company managed by Stiritz, where...
# 4  ORGANIZATION  Energizer is a company that was acquired by Ra...
#
#                                        text_unit_ids  frequency  degree  x  y
# 0  [7485ee648827c0f1cadb1e8b4af1b2dd5270a897b8235...          1      11  0  0
# 1  [7485ee648827c0f1cadb1e8b4af1b2dd5270a897b8235...          1       1  0  0
# 2  [7485ee648827c0f1cadb1e8b4af1b2dd5270a897b8235...          1       1  0  0
# 3  [7485ee648827c0f1cadb1e8b4af1b2dd5270a897b8235...          1       1  0  0
# 4  [7485ee648827c0f1cadb1e8b4af1b2dd5270a897b8235...          1       1  0  0

# %%
for i in range(entity_df.shape[0]):
    print(f"\n\nEntity : {entity_df.iloc[i]["title"]}    Type : {entity_df.iloc[i]["type"]}")
    print(f"Description : {entity_df.iloc[i]["description"]}")
# Out:
# Entity : STIRITZ    Type : PERSON
# Description : Stiritz is a business executive known for his independent and analytical approach to management, focusing on key financial metrics and avoiding traditional accounting measures. He is recognized for his strategic acquisitions and private equity-like mindset in managing Ralston, emphasizing cash flow and shareholder value.
#
#
# Entity : RAND ARASKOG    Type : PERSON
# Description : Rand Araskog was the chairman of ITT, from whom Stiritz sourced the Continental Baking acquisition through direct communication.
#
#
# Entity : PAT MULCAHY    Type : PERSON
# Description : Pat Mulcahy is a protégé of Stiritz who later ran the business and described Stiritz's approach to acquisitions, such as the Energizer acquisition.
#
#
# Entity : RALSTON    Type : ORGANIZATION
# Description : Ralston is a company managed by Stiritz, where he applied a private equity-like approach, focusing on cash flow and strategic acquisitions to enhance shareholder value.
#
#
# Entity : ENERGIZER    Type : ORGANIZATION
# Description : Energizer is a company that was acquired by Ralston under Stiritz's leadership, using a straightforward and focused acquisition strategy.
#
#
# Entity : NESTLÉ    Type : ORGANIZATION
# Description : Nestlé is a multinational food and beverage company involved in a multibillion-dollar deal with Stiritz, who negotiated aggressively with investment bankers.
#
#
# Entity : RJR NABISCO    Type : ORGANIZATION
# Description : RJR Nabisco is a company involved in a sale process where Stiritz participated in due diligence meetings, showcasing his independent approach.
#
#
# Entity : JOHN BIERBUSSE    Type : PERSON
# Description : John Bierbusse is a longtime analyst who commented on Stiritz's unconventional approach and his disregard for traditional accounting metrics.
#
#
# Entity : JOHN MCMILLIN    Type : PERSON
# Description : John McMillin is an industry analyst who described Stiritz as both an innovator and someone who borrows ideas, highlighting his adaptability and openness to new thinking.
#
#
# Entity : ITT    Type : ORGANIZATION
# Description : ITT is a company whose chairman, Rand Araskog, was directly contacted by Stiritz to acquire Continental Baking.
#
#
# Entity : GOLDMAN SACHS    Type : ORGANIZATION
# Description : Goldman Sachs is a leading global investment banking, securities, and investment management firm. Renowned for its comprehensive financial services, the firm plays a pivotal role in the global financial landscape, offering a wide range of services that include investment banking, securities, and investment management. As a prominent player in the financial sector, Goldman Sachs is involved in significant financial transactions and advisory roles across various industries. One notable instance of its involvement in major financial activities is during the RJR Nabisco sale process, where it hosted a due diligence session attended by Stiritz. This highlights Goldman Sachs' integral role in facilitating complex financial transactions and providing expert advisory services to its clients. Through its extensive expertise and global reach, Goldman Sachs continues to be a key institution in shaping financial markets and supporting the financial needs of corporations, governments, and individuals worldwide.
#
#
# Entity : CONTINENTAL BAKING    Type :
# Description :
#
#
# Entity : GENERAL CINEMA    Type : ORGANIZATION
# Description : General Cinema was a company involved in retail and publishing businesses, known for its strategic acquisitions and high shareholder returns
#
#
# Entity : HBJ    Type : ORGANIZATION
# Description : Harcourt Brace Jovanovich, a company acquired by General Cinema in 1991 for $1.56 billion
#
#
# Entity : DICK SMITH    Type : PERSON
# Description : Dick Smith was the CEO of General Cinema, known for generating high returns for shareholders and leading strategic acquisitions
#
#
# Entity : REED ELSEVIER    Type : ORGANIZATION
# Description : Reed Elsevier is a company that acquired HBJ's publishing assets from General Cinema in 2003
#
#
# Entity : NEIMAN MARCUS    Type : ORGANIZATION
# Description : Neiman Marcus was part of General Cinema's portfolio, sold to private equity buyers in 2006
#
#
# Entity : WOODY IVES    Type : PERSON
# Description : Woody Ives was the CFO of General Cinema and part of the Office of the Chairman
#
#
# Entity : BOB TARR    Type : PERSON
# Description : Bob Tarr was the COO of General Cinema and part of the Office of the Chairman
#
#
# Entity : SAM FRANKENHEIM    Type : PERSON
# Description : Sam Frankenheim was the corporate counsel of General Cinema and part of the Office of the Chairman
#
#
# Entity : CAESAR SWEITZER    Type : PERSON
# Description : Caesar Sweitzer was an investment banker associated with General Cinema, known for his characterization of HBJ's balance sheet
#
#
# Entity : CHESTNUT HILL    Type : GEO
# Description : Location of General Cinema's corporate headquarters in Massachusetts
#
#
# Entity : EASTERN RESOURCES    Type : ORGANIZATION
# Description : Company led by Woody Ives after leaving General Cinema
#
#
# Entity : PUTNAM    Type : ORGANIZATION
# Description : Investment firm where Bob Beck was an analyst covering General Cinema
#
#
# Entity : BOB BECK    Type : PERSON
# Description : Putnam analyst who commented on General Cinema's investor communications
#
#
# Entity : DAVID WARGO    Type : PERSON
# Description : Media investor who reported on General Cinema's strategic clarity and success post-HBJ acquisition
#
#
# Entity : TPG    Type : ORGANIZATION
# Description : TPG is a private equity firm involved in the purchase of Neiman Marcus from General Cinema
#
#
# Entity : WARBURG PINCUS    Type : ORGANIZATION
# Description : Warburg Pincus is a private equity firm involved in the purchase of Neiman Marcus from General Cinema
#
#
# Entity : GC COMPANIES    Type :
# Description :
#
#
# Entity : WARREN BUFFETT    Type : PERSON
# Description : Warren Buffett is a renowned investor and the chairman and CEO of Berkshire Hathaway, a multinational conglomerate holding company. He is widely recognized for his strategic investments and acquisitions, particularly during times of financial crises. One of his most notable actions was his significant investments following the 2008 Lehman Brothers collapse, which demonstrated his ability to identify and capitalize on opportunities during turbulent economic periods. Over the years, Buffett has evolved his investment strategy from traditional value investing, which focuses on undervalued stocks, to prioritizing companies with strong brands and solid market positions. This shift reflects his adaptability and keen insight into market dynamics, allowing him to maintain Berkshire Hathaway's success and growth. Buffett's investment philosophy and leadership have made him a highly respected figure in the financial world, earning him the nickname "Oracle of Omaha" for his remarkable foresight and investment acumen.
#
#
# Entity : CHARLIE MUNGER    Type : PERSON
# Description : Charlie Munger is the vice chairman of Berkshire Hathaway and a long-time business partner of Warren Buffett. He has played a significant role in influencing Buffett's investment strategy shift. As a key figure in the leadership of Berkshire Hathaway, Munger's insights and strategic thinking have been instrumental in shaping the company's direction and success. His partnership with Buffett is renowned in the business world, highlighting a collaboration that has been pivotal in the evolution of one of the most successful investment firms globally.
#
#
# Entity : BERKSHIRE HATHAWAY    Type : ORGANIZATION
# Description : Berkshire Hathaway is a multinational conglomerate holding company led by the renowned investor Warren Buffett. The company is distinguished by its diverse portfolio, which includes wholly owned companies and a wide array of stock investments. Known for its strategic investments and acquisitions, Berkshire Hathaway has established itself as a major player in various industries. Under Buffett's leadership, the company has consistently demonstrated a keen ability to identify and capitalize on lucrative investment opportunities, contributing to its reputation as a powerhouse in the global market.
#
#
# Entity : SEE'S CANDIES    Type : ORGANIZATION
# Description : See's Candies is a confectionery company acquired by Berkshire Hathaway in 1972, known for its strong brand and pricing power
#
#
# Entity : BUFFALO NEWS    Type : ORGANIZATION
# Description : The Buffalo News is a newspaper owned by Berkshire Hathaway, part of its media investments
#
#
# Entity : WASHINGTON POST    Type : ORGANIZATION
# Description : The Washington Post is a major American newspaper in which Berkshire Hathaway held a significant stock position
#
#
# Entity : GEICO    Type : ORGANIZATION
# Description : GEICO, an insurance company, is wholly owned by Berkshire Hathaway. The company became a part of Berkshire Hathaway's portfolio when Warren Buffett, the chairman and CEO of Berkshire Hathaway, partially acquired it in 1996. Over time, GEICO has grown to become a significant contributor to Berkshire Hathaway's portfolio, reflecting its importance and value within the conglomerate.
#
#
# Entity : GENERAL FOODS    Type : ORGANIZATION
# Description : General Foods was a major food company in which Berkshire Hathaway held a large stock position
#
#
# Entity : NEBRASKA FURNITURE MART    Type : ORGANIZATION
# Description : Nebraska Furniture Mart is a large furniture retailer acquired by Berkshire Hathaway in 1983
#
#
# Entity : SCOTT FETZER    Type : ORGANIZATION
# Description : Scott Fetzer is a conglomerate of niche industrial businesses acquired by Berkshire Hathaway in 1985
#
#
# Entity : CAPITAL CITIES/ABC    Type : ORGANIZATION
# Description : Capital Cities/ABC is a media company in which Berkshire Hathaway acquired an 18% stake in 1986
#
#
# Entity : COCA-COLA COMPANY    Type : ORGANIZATION
# Description : The Coca-Cola Company is a major beverage corporation in which Berkshire Hathaway made a significant investment in 1989
#
#
# Entity : SALOMON BROTHERS    Type : ORGANIZATION
# Description : Salomon Brothers was an investment bank involved in a financial scandal, with Warren Buffett serving as interim CEO to navigate the crisis
#
#
# Entity : WELLS FARGO    Type : ORGANIZATION
# Description : Wells Fargo is a financial services company in which Berkshire Hathaway made a large investment in 1990
#
#
# Entity : GENERAL DYNAMICS    Type : ORGANIZATION
# Description : General Dynamics is an aerospace and defense company in which Berkshire Hathaway made a significant investment in 1992
#
#
# Entity : AMERICAN EXPRESS    Type : ORGANIZATION
# Description : American Express is a multinational financial services corporation that gained significant attention in 1994 when Berkshire Hathaway made a substantial investment in the company. Known for its global presence and diverse range of financial products and services, American Express has established itself as a key player in the financial industry. The investment by Berkshire Hathaway, a renowned conglomerate led by Warren Buffett, underscored the confidence in American Express's business model and growth potential during that period. This strategic move highlighted the corporation's robust market position and its appeal to major investors.
#
#
# Entity : GENERAL RE    Type : ORGANIZATION
# Description : General Re is a prominent reinsurer that was acquired by Berkshire Hathaway in 1998. This acquisition was a significant milestone, as it marked the largest transaction in Berkshire Hathaway's history, with a deal valued at $22 billion.
#
#
# Entity : CHUCK HUGGINS    Type : PERSON
# Description : Chuck Huggins was installed as the CEO of See's Candies after its acquisition by Berkshire Hathaway
#
#
# Entity : OMAHA    Type : GEO
# Description : Omaha is a prominent city located in the state of Nebraska. It is widely recognized as the home of Warren Buffett, one of the most successful investors in the world. Omaha serves as the headquarters for Berkshire Hathaway, the multinational conglomerate holding company led by Buffett. This city is not only significant for its association with Buffett but also for its role in the operations of Berkshire Hathaway. Additionally, Omaha is noted for being the location where See's Candies, a subsidiary of Berkshire Hathaway, directs its free cash flow. This highlights Omaha's importance as a central hub for major business activities and financial operations related to one of the most influential companies in the world.
#
#
# Entity : SANDY WEILL    Type : PERSON
# Description : Sandy Weill was the CEO of Travelers Corporation, which acquired Salomon Brothers
#
#
# Entity : TRAVELERS CORPORATION    Type : ORGANIZATION
# Description : Travelers Corporation acquired Salomon Brothers, where Warren Buffett served as interim CEO
#
#
# Entity : TOM MURPHY    Type :
# Description :
#
#
# Entity : SHAW CARPETS    Type : ORGANIZATION
# Description : Shaw Carpets is a company acquired by Warren Buffett in the late 1990s and early 2000s
#
#
# Entity : BENJAMIN MOORE PAINTS    Type : ORGANIZATION
# Description : Benjamin Moore Paints is a company acquired by Warren Buffett in the late 1990s and early 2000s
#
#
# Entity : CLAYTON HOMES    Type : ORGANIZATION
# Description : Clayton Homes is a company acquired by Warren Buffett in the late 1990s and early 2000s
#
#
# Entity : MIDAMERICAN ENERGY    Type : ORGANIZATION
# Description : MidAmerican Energy is an electric utility company in which Warren Buffett made significant investments
#
#
# Entity : WALTER SCOTT    Type : PERSON
# Description : Walter Scott is a friend of Warren Buffett and the former CEO of Kiewit Construction, involved in a joint venture with MidAmerican Energy
#
#
# Entity : ISTAR    Type : ORGANIZATION
# Description : Istar is a leading manufacturer of cutting tools and blades based in Israel, acquired by Berkshire Hathaway in 2006
#
#
# Entity : BURLINGTON NORTHERN SANTA FE    Type : ORGANIZATION
# Description : Burlington Northern Santa Fe is the largest railroad in the United States, acquired by Berkshire Hathaway in 2010
#
#
# Entity : NATIONAL INDEMNITY    Type : ORGANIZATION
# Description : National Indemnity is a property and casualty insurer acquired by Warren Buffett in 1967, known for its unique approach to underwriting and float generation
#
#
# Entity : LEHMAN BROTHERS BANKRUPTCY    Type : EVENT
# Description : The Lehman Brothers bankruptcy in 2008 was a major event in the global financial crisis, marking the largest bankruptcy filing in U.S. history
#
#
# Entity : SEPTEMBER 11 TERRORIST ATTACKS    Type :
# Description :
#
#
# Entity : JOHN MALONE    Type : PERSON
# Description : John Malone is a CEO known for his aggressive capital allocation strategies, particularly during the financial crisis, involving Liberty Media and its entities
#
#
# Entity : LEHMAN BROTHERS    Type : ORGANIZATION
# Description : Lehman Brothers was a global financial services firm whose collapse in September 2008 triggered a financial meltdown
#
#
# Entity : GENERAL ELECTRIC    Type : ORGANIZATION
# Description : General Electric is a multinational conglomerate corporation involved in various sectors including aviation, power, and renewable energy
#
#
# Entity : CONSTELLATION ENERGY    Type : ORGANIZATION
# Description : Constellation Energy is a company involved in energy production and distribution
#
#
# Entity : MARS/WRIGLEY    Type : ORGANIZATION
# Description : Mars/Wrigley is a global manufacturer of confectionery, pet food, and other food products
#
#
# Entity : DOW CHEMICAL    Type : ORGANIZATION
# Description : Dow Chemical is a multinational chemical corporation
#
#
# Entity : BURLINGTON NORTHERN    Type : ORGANIZATION
# Description : Burlington Northern is a major freight railroad network in North America
#
#
# Entity : LUBRIZOL    Type : ORGANIZATION
# Description : Lubrizol is a company specializing in specialty chemicals for transportation, industrial, and consumer markets
#
#
# Entity : IBM    Type : ORGANIZATION
# Description : IBM is a multinational technology and consulting company
#
#
# Entity : LIBERTY MEDIA    Type : ORGANIZATION
# Description : Liberty Media is a mass media company with interests in various entertainment and communications businesses
#
#
# Entity : DIRECTV    Type : ORGANIZATION
# Description : DIRECTV is a satellite television service provider
#
#
# Entity : STARZ/ENCORE    Type : ORGANIZATION
# Description : Starz/Encore is a premium cable and satellite television network
#
#
# Entity : LIBERTY CAPITAL    Type : ORGANIZATION
# Description : Liberty Capital is a division of Liberty Media involved in various investments and asset management
#
#
# Entity : LIBERTY INTERACTIVE    Type : ORGANIZATION
# Description : Liberty Interactive is a division of Liberty Media that includes QVC and other online retail entities
#
#
# Entity : SIRIUS BROADCASTING    Type : ORGANIZATION
# Description : Sirius Broadcasting is a satellite radio service provider
#
#
# Entity : LIBERTY GLOBAL    Type : ORGANIZATION
# Description : Liberty Global is an international telecommunications and television company
#
#
# Entity : UNITYMEDIA    Type : ORGANIZATION
# Description : Unitymedia is a German cable company acquired by Liberty Global
#
#
# Entity : LOUIS PASTEUR    Type : PERSON
# Description : Louis Pasteur was a French biologist, microbiologist, and chemist renowned for his discoveries of the principles of vaccination, microbial fermentation, and pasteurization
#
#
# Entity : SEPTEMBER 2008 COLLAPSE OF LEHMAN BROTHERS    Type : EVENT
# Description : The September 2008 collapse of Lehman Brothers was a major event that triggered a global financial crisis
#
#
# Entity : RUDYARD KIPLING    Type :
# Description :
#
#
# Entity : ATUL GAWANDE    Type : PERSON
# Description : Atul Gawande is an author known for his book "The Checklist Manifesto," which discusses the effectiveness of checklists in decision-making
#
#
# Entity : THE CHECKLIST MANIFESTO    Type : EVENT
# Description : A book by Atul Gawande that highlights the power of checklists in various fields such as aviation, medicine, and construction
#
#
# Entity : OUTSIDER CEOS    Type : PERSON
# Description : CEOs who adopt unconventional approaches to resource allocation and decision-making, often leading to exceptional business results
#
#
# Entity : BAKER    Type : PERSON
# Description : An entrepreneur managing a local business, facing similar decision-making challenges as larger corporations
#
#
# Entity : KAHNEMAN'S SYSTEM 2    Type : EVENT
# Description : A concept from psychology referring to the deliberate and analytical mode of thinking
#
#
# Entity : FORTUNE 500 CEO    Type :
# Description :
#
#
# Entity : OUTSIDER APPROACH    Type : EVENT
# Description : The outsider approach is a method for resource allocation in business that has generated exceptional results across various industries and market conditions
#
#
# Entity : NEIGHBORHOOD BAKERY    Type : ORGANIZATION
# Description : A small business that can benefit from the outsider approach to resource allocation
#
#
# Entity : MULTINATIONAL CONGLOMERATE    Type : ORGANIZATION
# Description : A large business entity that can adopt the outsider approach to resource allocation
#
#
# Entity : STOCK    Type : ORGANIZATION
# Description : Stock represents shares in a company that can be sold when prices are extremely high
#
#
# Entity : BUSINESSES    Type :
# Description :

# %% [markdown]
# ### Relationships

# %%
relationships_df.head()
# Out:
#                                      id  human_readable_id   source  \
# 0  120af309-2f80-4803-bf4a-c3242c86f709                  0  STIRITZ
# 1  9e7adeca-64f2-400a-afe1-c2f6fe5c083d                  1  STIRITZ
# 2  9d2cc701-2bd5-42c9-811e-02338e59c371                  2  STIRITZ
# 3  abaf7ac6-c3d1-47e3-8379-3b2b22512397                  3  STIRITZ
# 4  cfb660ce-aa04-43c4-af47-d4a7efc40d59                  4  STIRITZ
#
#          target                                        description  weight  \
# 0       RALSTON  Stiritz managed Ralston with a private equity-...     9.0
# 1  RAND ARASKOG  Stiritz sourced the Continental Baking acquisi...     7.0
# 2   PAT MULCAHY  Pat Mulcahy was a protégé of Stiritz and later...     8.0
# 3     ENERGIZER  Stiritz led the acquisition of Energizer with ...     8.0
# 4        NESTLÉ  Stiritz negotiated a multibillion-dollar deal ...     7.0
#
#    combined_degree                                      text_unit_ids
# 0               12  [7485ee648827c0f1cadb1e8b4af1b2dd5270a897b8235...
# 1               12  [7485ee648827c0f1cadb1e8b4af1b2dd5270a897b8235...
# 2               12  [7485ee648827c0f1cadb1e8b4af1b2dd5270a897b8235...
# 3               12  [7485ee648827c0f1cadb1e8b4af1b2dd5270a897b8235...
# 4               12  [7485ee648827c0f1cadb1e8b4af1b2dd5270a897b8235...

# %%
for i in range(relationships_df.shape[0]):
    print(f"\n\nSource : {relationships_df.iloc[i]["source"]}    Target : {relationships_df.iloc[i]["target"]}    Weight : {relationships_df.iloc[i]["weight"]}")
    print(f"Description : {relationships_df.iloc[i]["description"]}")
# Out:
# Source : STIRITZ    Target : RALSTON    Weight : 9.0
# Description : Stiritz managed Ralston with a private equity-like approach, focusing on cash flow and strategic acquisitions
#
#
# Source : STIRITZ    Target : RAND ARASKOG    Weight : 7.0
# Description : Stiritz sourced the Continental Baking acquisition from Rand Araskog through direct communication
#
#
# Source : STIRITZ    Target : PAT MULCAHY    Weight : 8.0
# Description : Pat Mulcahy was a protégé of Stiritz and later ran the business, adopting his strategic approach
#
#
# Source : STIRITZ    Target : ENERGIZER    Weight : 8.0
# Description : Stiritz led the acquisition of Energizer with a focused and straightforward strategy
#
#
# Source : STIRITZ    Target : NESTLÉ    Weight : 7.0
# Description : Stiritz negotiated a multibillion-dollar deal with Nestlé, showcasing his aggressive approach with investment bankers
#
#
# Source : STIRITZ    Target : RJR NABISCO    Weight : 6.0
# Description : Stiritz participated in the RJR Nabisco sale process, demonstrating his independent and analytical approach
#
#
# Source : STIRITZ    Target : JOHN BIERBUSSE    Weight : 5.0
# Description : John Bierbusse commented on Stiritz's unconventional approach and disregard for traditional metrics
#
#
# Source : STIRITZ    Target : JOHN MCMILLIN    Weight : 1.0
# Description : John McMillin described Stiritz as both an innovator and someone who borrows ideas, highlighting his adaptability
#
#
# Source : STIRITZ    Target : CONTINENTAL BAKING    Weight : 8.0
# Description : Stiritz acquired Continental Baking by directly contacting ITT chairman Rand Araskog
#
#
# Source : STIRITZ    Target : ITT    Weight : 7.0
# Description : Stiritz sourced the Continental Baking acquisition from ITT through direct communication with its chairman
#
#
# Source : STIRITZ    Target : GOLDMAN SACHS    Weight : 1.0
# Description : Stiritz attended a due diligence session at Goldman Sachs during the RJR Nabisco sale process
#
#
# Source : GENERAL CINEMA    Target : HBJ    Weight : 8.0
# Description : General Cinema acquired HBJ in 1991 for $1.56 billion
#
#
# Source : GENERAL CINEMA    Target : DICK SMITH    Weight : 9.0
# Description : Dick Smith was the CEO of General Cinema
#
#
# Source : GENERAL CINEMA    Target : REED ELSEVIER    Weight : 7.0
# Description : General Cinema sold HBJ's publishing assets to Reed Elsevier in 2003
#
#
# Source : GENERAL CINEMA    Target : NEIMAN MARCUS    Weight : 6.0
# Description : General Cinema sold Neiman Marcus to private equity buyers in 2006
#
#
# Source : GENERAL CINEMA    Target : WOODY IVES    Weight : 8.0
# Description : Woody Ives was the CFO of General Cinema and part of the Office of the Chairman
#
#
# Source : GENERAL CINEMA    Target : BOB TARR    Weight : 8.0
# Description : Bob Tarr was the COO of General Cinema and part of the Office of the Chairman
#
#
# Source : GENERAL CINEMA    Target : SAM FRANKENHEIM    Weight : 8.0
# Description : Sam Frankenheim was the corporate counsel of General Cinema and part of the Office of the Chairman
#
#
# Source : GENERAL CINEMA    Target : CAESAR SWEITZER    Weight : 5.0
# Description : Caesar Sweitzer was an investment banker associated with General Cinema
#
#
# Source : GENERAL CINEMA    Target : CHESTNUT HILL    Weight : 5.0
# Description : General Cinema's corporate headquarters was located in Chestnut Hill, Massachusetts
#
#
# Source : GENERAL CINEMA    Target : PUTNAM    Weight : 3.0
# Description : Putnam analyst Bob Beck covered General Cinema
#
#
# Source : GENERAL CINEMA    Target : BOB BECK    Weight : 3.0
# Description : Bob Beck was a Putnam analyst who commented on General Cinema's investor communications
#
#
# Source : GENERAL CINEMA    Target : DAVID WARGO    Weight : 1.0
# Description : David Wargo reported on General Cinema's strategic clarity and success post-HBJ acquisition
#
#
# Source : GENERAL CINEMA    Target : GC COMPANIES    Weight : 7.0
# Description : General Cinema spun off its theater business into GC Companies
#
#
# Source : NEIMAN MARCUS    Target : TPG    Weight : 6.0
# Description : TPG was involved in the purchase of Neiman Marcus from General Cinema
#
#
# Source : NEIMAN MARCUS    Target : WARBURG PINCUS    Weight : 1.0
# Description : Warburg Pincus was involved in the purchase of Neiman Marcus from General Cinema
#
#
# Source : WOODY IVES    Target : EASTERN RESOURCES    Weight : 4.0
# Description : Woody Ives led Eastern Resources after leaving General Cinema
#
#
# Source : WARREN BUFFETT    Target : CHARLIE MUNGER    Weight : 8.0
# Description : Charlie Munger influenced Warren Buffett's shift in investment strategy
#
#
# Source : WARREN BUFFETT    Target : BERKSHIRE HATHAWAY    Weight : 29.0
# Description : Warren Buffett is the chairman and CEO of Berkshire Hathaway, a multinational conglomerate holding company. Under his leadership, Buffett has been instrumental in shaping the company's investment strategies and guiding its strategic acquisitions. As both chairman and CEO, he has played a pivotal role in steering Berkshire Hathaway towards significant growth and success. His expertise in investments and acquisitions has been a cornerstone of the company's operations, allowing it to expand its portfolio and maintain a strong presence in various industries. Through his visionary leadership, Warren Buffett has established Berkshire Hathaway as a prominent and influential entity in the global market.
#
#
# Source : WARREN BUFFETT    Target : SALOMON BROTHERS    Weight : 9.0
# Description : Warren Buffett served as interim CEO of Salomon Brothers during a financial scandal
#
#
# Source : WARREN BUFFETT    Target : TOM MURPHY    Weight : 7.0
# Description : Warren Buffett helped Tom Murphy, CEO of Capital Cities, acquire ABC
#
#
# Source : WARREN BUFFETT    Target : CHUCK HUGGINS    Weight : 6.0
# Description : Warren Buffett and Charlie Munger installed Chuck Huggins as CEO of See's Candies
#
#
# Source : WARREN BUFFETT    Target : SANDY WEILL    Weight : 6.0
# Description : Sandy Weill's Travelers Corporation acquired Salomon Brothers, where Buffett was interim CEO
#
#
# Source : BERKSHIRE HATHAWAY    Target : SEE'S CANDIES    Weight : 9.0
# Description : Berkshire Hathaway acquired See's Candies in 1972
#
#
# Source : BERKSHIRE HATHAWAY    Target : BUFFALO NEWS    Weight : 7.0
# Description : Berkshire Hathaway owns the Buffalo News
#
#
# Source : BERKSHIRE HATHAWAY    Target : WASHINGTON POST    Weight : 7.0
# Description : Berkshire Hathaway held a significant stock position in the Washington Post
#
#
# Source : BERKSHIRE HATHAWAY    Target : GEICO    Weight : 9.0
# Description : Berkshire Hathaway owns GEICO
#
#
# Source : BERKSHIRE HATHAWAY    Target : GENERAL FOODS    Weight : 6.0
# Description : Berkshire Hathaway held a large stock position in General Foods
#
#
# Source : BERKSHIRE HATHAWAY    Target : NEBRASKA FURNITURE MART    Weight : 8.0
# Description : Berkshire Hathaway acquired Nebraska Furniture Mart in 1983
#
#
# Source : BERKSHIRE HATHAWAY    Target : SCOTT FETZER    Weight : 8.0
# Description : Berkshire Hathaway acquired Scott Fetzer in 1985
#
#
# Source : BERKSHIRE HATHAWAY    Target : CAPITAL CITIES/ABC    Weight : 7.0
# Description : Berkshire Hathaway acquired an 18% stake in Capital Cities/ABC in 1986
#
#
# Source : BERKSHIRE HATHAWAY    Target : COCA-COLA COMPANY    Weight : 8.0
# Description : Berkshire Hathaway made a significant investment in the Coca-Cola Company in 1989
#
#
# Source : BERKSHIRE HATHAWAY    Target : WELLS FARGO    Weight : 7.0
# Description : Berkshire Hathaway made a large investment in Wells Fargo in 1990
#
#
# Source : BERKSHIRE HATHAWAY    Target : GENERAL DYNAMICS    Weight : 7.0
# Description : Berkshire Hathaway made a significant investment in General Dynamics in 1992
#
#
# Source : BERKSHIRE HATHAWAY    Target : AMERICAN EXPRESS    Weight : 7.0
# Description : Berkshire Hathaway made a large investment in American Express in 1994
#
#
# Source : BERKSHIRE HATHAWAY    Target : GENERAL RE    Weight : 1.0
# Description : Berkshire Hathaway acquired General Re in 1998
#
#
# Source : SEE'S CANDIES    Target : OMAHA    Weight : 5.0
# Description : See's Candies sent $1.65 billion in free cash to Omaha, where Berkshire Hathaway is headquartered
#
#
# Source : SALOMON BROTHERS    Target : TRAVELERS CORPORATION    Weight : 1.0
# Description : Travelers Corporation acquired Salomon Brothers
#
#
# Source : WARREN BUFFETT    Target : GEICO    Weight : 8.0
# Description : Warren Buffett acquired half of GEICO in 1996
#
#
# Source : WARREN BUFFETT    Target : GENERAL RE    Weight : 8.0
# Description : Warren Buffett acquired General Re in 1998 for $22 billion
#
#
# Source : WARREN BUFFETT    Target : SHAW CARPETS    Weight : 6.0
# Description : Warren Buffett acquired Shaw Carpets in the late 1990s and early 2000s
#
#
# Source : WARREN BUFFETT    Target : BENJAMIN MOORE PAINTS    Weight : 6.0
# Description : Warren Buffett acquired Benjamin Moore Paints in the late 1990s and early 2000s
#
#
# Source : WARREN BUFFETT    Target : CLAYTON HOMES    Weight : 6.0
# Description : Warren Buffett acquired Clayton Homes in the late 1990s and early 2000s
#
#
# Source : WARREN BUFFETT    Target : MIDAMERICAN ENERGY    Weight : 7.0
# Description : Warren Buffett made significant investments in MidAmerican Energy
#
#
# Source : WARREN BUFFETT    Target : ISTAR    Weight : 7.0
# Description : Warren Buffett acquired Istar in 2006
#
#
# Source : WARREN BUFFETT    Target : BURLINGTON NORTHERN SANTA FE    Weight : 9.0
# Description : Warren Buffett acquired Burlington Northern Santa Fe in 2010
#
#
# Source : WARREN BUFFETT    Target : NATIONAL INDEMNITY    Weight : 8.0
# Description : Warren Buffett acquired National Indemnity in 1967, recognizing the leverage in insurance float
#
#
# Source : WARREN BUFFETT    Target : OMAHA    Weight : 1.0
# Description : Omaha is the home of Warren Buffett and the location of Berkshire Hathaway's headquarters
#
#
# Source : BERKSHIRE HATHAWAY    Target : CHARLIE MUNGER    Weight : 9.0
# Description : Charlie Munger is the vice chairman of Berkshire Hathaway and a key contributor to its success
#
#
# Source : BERKSHIRE HATHAWAY    Target : LEHMAN BROTHERS BANKRUPTCY    Weight : 7.0
# Description : The Lehman Brothers bankruptcy marked the beginning of one of the most active investing periods for Berkshire Hathaway
#
#
# Source : SHAW CARPETS    Target : SEPTEMBER 11 TERRORIST ATTACKS    Weight : 5.0
# Description : Shaw Carpets was acquired by Warren Buffett in a period when industries were out of favor after the September 11 terrorist attacks
#
#
# Source : BENJAMIN MOORE PAINTS    Target : SEPTEMBER 11 TERRORIST ATTACKS    Weight : 5.0
# Description : Benjamin Moore Paints was acquired by Warren Buffett in a period when industries were out of favor after the September 11 terrorist attacks
#
#
# Source : CLAYTON HOMES    Target : SEPTEMBER 11 TERRORIST ATTACKS    Weight : 5.0
# Description : Clayton Homes was acquired by Warren Buffett in a period when industries were out of favor after the September 11 terrorist attacks
#
#
# Source : MIDAMERICAN ENERGY    Target : WALTER SCOTT    Weight : 1.0
# Description : Walter Scott was involved in a joint venture with MidAmerican Energy
#
#
# Source : WARREN BUFFETT    Target : LEHMAN BROTHERS    Weight : 8.0
# Description : Warren Buffett made significant investments following the collapse of Lehman Brothers
#
#
# Source : WARREN BUFFETT    Target : SEPTEMBER 2008 COLLAPSE OF LEHMAN BROTHERS    Weight : 8.0
# Description : Warren Buffett made significant investments following the financial crisis triggered by the collapse of Lehman Brothers
#
#
# Source : JOHN MALONE    Target : LIBERTY MEDIA    Weight : 9.0
# Description : John Malone is associated with Liberty Media and its strategic financial maneuvers
#
#
# Source : JOHN MALONE    Target : LEHMAN BROTHERS    Weight : 7.0
# Description : John Malone's strategies were influenced by the financial crisis following Lehman Brothers' collapse
#
#
# Source : JOHN MALONE    Target : SEPTEMBER 2008 COLLAPSE OF LEHMAN BROTHERS    Weight : 7.0
# Description : John Malone's financial strategies were influenced by the crisis following the collapse of Lehman Brothers
#
#
# Source : GOLDMAN SACHS    Target : BERKSHIRE HATHAWAY    Weight : 7.0
# Description : Berkshire Hathaway, under Warren Buffett, invested in Goldman Sachs
#
#
# Source : GENERAL ELECTRIC    Target : BERKSHIRE HATHAWAY    Weight : 7.0
# Description : Berkshire Hathaway, under Warren Buffett, invested in General Electric
#
#
# Source : CONSTELLATION ENERGY    Target : BERKSHIRE HATHAWAY    Weight : 6.0
# Description : Berkshire Hathaway, under Warren Buffett, invested in Constellation Energy
#
#
# Source : MARS/WRIGLEY    Target : BERKSHIRE HATHAWAY    Weight : 6.0
# Description : Berkshire Hathaway provided mezzanine financing to Mars/Wrigley
#
#
# Source : DOW CHEMICAL    Target : BERKSHIRE HATHAWAY    Weight : 6.0
# Description : Berkshire Hathaway provided mezzanine financing to Dow Chemical
#
#
# Source : BERKSHIRE HATHAWAY    Target : BURLINGTON NORTHERN    Weight : 8.0
# Description : Berkshire Hathaway acquired the remaining shares of Burlington Northern
#
#
# Source : BERKSHIRE HATHAWAY    Target : LUBRIZOL    Weight : 7.0
# Description : Berkshire Hathaway acquired Lubrizol
#
#
# Source : BERKSHIRE HATHAWAY    Target : IBM    Weight : 7.0
# Description : Berkshire Hathaway made a significant investment in IBM
#
#
# Source : LIBERTY MEDIA    Target : DIRECTV    Weight : 8.0
# Description : Liberty Media, under John Malone, implemented a leveraged equity growth strategy at DIRECTV
#
#
# Source : LIBERTY MEDIA    Target : STARZ/ENCORE    Weight : 6.0
# Description : Liberty Media spun off Starz/Encore
#
#
# Source : LIBERTY CAPITAL    Target : LIBERTY INTERACTIVE    Weight : 7.0
# Description : Liberty Capital and Liberty Interactive engaged in a debt-for-equity swap
#
#
# Source : LIBERTY CAPITAL    Target : SIRIUS BROADCASTING    Weight : 8.0
# Description : Liberty Capital acquired control of Sirius Broadcasting
#
#
# Source : LIBERTY GLOBAL    Target : UNITYMEDIA    Weight : 1.0
# Description : Liberty Global acquired Unitymedia
#
#
# Source : LOUIS PASTEUR    Target : RUDYARD KIPLING    Weight : 1.0
# Description : Both Rudyard Kipling and Louis Pasteur are quoted or referenced in the context of the text
#
#
# Source : ATUL GAWANDE    Target : THE CHECKLIST MANIFESTO    Weight : 9.0
# Description : Atul Gawande is the author of "The Checklist Manifesto"
#
#
# Source : THE CHECKLIST MANIFESTO    Target : OUTSIDER CEOS    Weight : 1.0
# Description : The checklist approach discussed in "The Checklist Manifesto" is used by outsider CEOs to make effective resource allocation decisions
#
#
# Source : THE CHECKLIST MANIFESTO    Target : KAHNEMAN'S SYSTEM 2    Weight : 1.0
# Description : The checklist approach engages Kahneman's System 2 for analytical decision-making
#
#
# Source : BAKER    Target : FORTUNE 500 CEO    Weight : 6.0
# Description : Both face similar decision-making challenges in capital allocation, despite the difference in scale
#
#
# Source : OUTSIDER APPROACH    Target : NEIGHBORHOOD BAKERY    Weight : 5.0
# Description : The outsider approach can be applied to a neighborhood bakery to improve resource allocation
#
#
# Source : OUTSIDER APPROACH    Target : MULTINATIONAL CONGLOMERATE    Weight : 1.0
# Description : The outsider approach can be adopted by a multinational conglomerate to enhance resource allocation
#
#
# Source : OUTSIDER APPROACH    Target : BUSINESSES    Weight : 6.0
# Description : Businesses can use the outsider approach for better resource allocation and decision-making
#
#
# Source : OUTSIDER APPROACH    Target : STOCK    Weight : 1.0
# Description : The outsider approach can guide decisions on selling stock when prices are high

# %% [markdown]
# ### Communities

# %%
community_report_df.head()
# Out:
#                                  id  human_readable_id  community  level  \
# 0  61a89e0dcd6f439c9ff1bb7e0f72abd4                 10         10      3
# 1  29e4baf803514b2d9b4acfbddf71843f                 11         11      3
# 2  55fb0feaed634ac8a0a61daf249ea066                  8          8      2
# 3  41ee7f7b00b842aaa83bd8e62de97432                  9          9      2
# 4  f431a039091441e7989bb6c8ec3a6474                  4          4      1
#
#    parent  children                                              title  \
# 0       8        []  Berkshire Hathaway and Warren Buffett's Invest...
# 1       8        []                MidAmerican Energy and Walter Scott
# 2       7  [10, 11]             Berkshire Hathaway and Key Investments
# 3       7        []         Salomon Brothers and Travelers Corporation
# 4       0        []   Berkshire Hathaway and Its Strategic Investments
#
#                                              summary  \
# 0  The community is centered around Berkshire Hat...
# 1  The community is centered around MidAmerican E...
# 2  The community is centered around Berkshire Hat...
# 3  The community is centered around Salomon Broth...
# 4  The community is centered around Berkshire Hat...
#
#                                         full_content  rank  \
# 0  # Berkshire Hathaway and Warren Buffett's Inve...   9.5
# 1  # MidAmerican Energy and Walter Scott\n\nThe c...   6.5
# 2  # Berkshire Hathaway and Key Investments\n\nTh...   9.5
# 3  # Salomon Brothers and Travelers Corporation\n...   7.5
# 4  # Berkshire Hathaway and Its Strategic Investm...   9.5
#
#                                   rating_explanation  \
# 0  The impact severity rating is high due to Berk...
# 1  The impact severity rating is moderately high ...
# 2  The impact severity rating is high due to Berk...
# 3  The impact severity rating is high due to the ...
# 4  The impact severity rating is high due to Berk...
#
#                                             findings  \
# 0  [{'explanation': 'Warren Buffett, as the chair...
# 1  [{'explanation': 'MidAmerican Energy is a cent...
# 2  [{'explanation': 'Warren Buffett, as the chair...
# 3  [{'explanation': 'Salomon Brothers was an inve...
# 4  [{'explanation': 'Berkshire Hathaway, under th...
#
#                                    full_content_json      period  size
# 0  {\n    "title": "Berkshire Hathaway and Warren...  2025-05-02    10
# 1  {\n    "title": "MidAmerican Energy and Walter...  2025-05-02     2
# 2  {\n    "title": "Berkshire Hathaway and Key In...  2025-05-02    12
# 3  {\n    "title": "Salomon Brothers and Traveler...  2025-05-02     2
# 4  {\n    "title": "Berkshire Hathaway and Its St...  2025-05-02    20

# %%
for i in range(community_report_df.shape[0]):
    print(f"\n\nTitle : {community_report_df.iloc[i]["title"]}   Rank : {community_report_df.iloc[i]["rank"]}")
    print(f"Rating Explanation : {community_report_df.iloc[i]["rating_explanation"]}")
    print(f"\nSummary : {community_report_df.iloc[i]["summary"]}")
# Out:
# Title : Berkshire Hathaway and Warren Buffett's Investment Network   Rank : 9.5
# Rating Explanation : The impact severity rating is high due to Berkshire Hathaway's significant influence in the global financial markets and its strategic investments across various industries.
#
# Summary : The community is centered around Berkshire Hathaway, a multinational conglomerate led by Warren Buffett, with significant contributions from Charlie Munger. Key entities include major acquisitions such as GEICO, General Re, and Burlington Northern Santa Fe, which highlight Buffett's strategic investment approach. The relationships within this network demonstrate a focus on insurance, transportation, and strategic partnerships, reflecting a diversified investment strategy that has been pivotal in Berkshire Hathaway's growth and influence.
#
#
# Title : MidAmerican Energy and Walter Scott   Rank : 6.5
# Rating Explanation : The impact severity rating is moderately high due to the involvement of high-profile individuals and significant financial investments.
#
# Summary : The community is centered around MidAmerican Energy, an electric utility company, and its relationship with Walter Scott, a former CEO of Kiewit Construction. Walter Scott's involvement in a joint venture with MidAmerican Energy highlights the interconnectedness of these entities, with significant investments from Warren Buffett adding to the community's importance.
#
#
# Title : Berkshire Hathaway and Key Investments   Rank : 9.5
# Rating Explanation : The impact severity rating is high due to Berkshire Hathaway's substantial influence in multiple industries and its strategic investment decisions.
#
# Summary : The community is centered around Berkshire Hathaway, led by Warren Buffett and Charlie Munger, with significant investments in various industries. Key entities include GEICO, General Re, and Burlington Northern Santa Fe, among others. The relationships highlight strategic acquisitions and leadership decisions that have shaped the conglomerate's success.
#
#
# Title : Salomon Brothers and Travelers Corporation   Rank : 7.5
# Rating Explanation : The impact severity rating is high due to the involvement of major financial entities and the significant leadership role played by Warren Buffett during a critical period.
#
# Summary : The community is centered around Salomon Brothers, an investment bank involved in a financial scandal, and its acquisition by Travelers Corporation. Warren Buffett played a crucial role as interim CEO during the crisis at Salomon Brothers, which was later acquired by Travelers Corporation, highlighting significant corporate restructuring and leadership dynamics.
#
#
# Title : Berkshire Hathaway and Its Strategic Investments   Rank : 9.5
# Rating Explanation : The impact severity rating is high due to Berkshire Hathaway's extensive influence and strategic investments across multiple major industries.
#
# Summary : The community is centered around Berkshire Hathaway, a multinational conglomerate led by Warren Buffett, known for its strategic investments and acquisitions across various industries. Key entities include major companies like Goldman Sachs, Coca-Cola, and American Express, among others. The relationships highlight Berkshire Hathaway's significant influence in the global market through its diverse portfolio, which includes wholly owned companies and substantial stock positions in leading corporations.
#
#
# Title : Omaha and See's Candies Financial Network   Rank : 8.5
# Rating Explanation : The impact severity rating is high due to the substantial financial activities and the influence of Berkshire Hathaway in the global market.
#
# Summary : This community is centered around Omaha, Nebraska, which serves as the headquarters for Berkshire Hathaway, and See's Candies, a subsidiary of Berkshire Hathaway. The relationship between these entities is highlighted by the significant financial transactions, specifically the transfer of $1.65 billion in free cash from See's Candies to Omaha, underscoring Omaha's role as a financial hub for Berkshire Hathaway's operations.
#
#
# Title : Warren Buffett's Acquisitions Post-9/11   Rank : 7.5
# Rating Explanation : The impact severity rating is high due to the significant influence of Warren Buffett's investment decisions on the market and the strategic timing of these acquisitions post-9/11.
#
# Summary : This community centers around the acquisitions made by Warren Buffett in the late 1990s and early 2000s, specifically focusing on Shaw Carpets, Benjamin Moore Paints, and Clayton Homes. These acquisitions occurred during a period when industries were generally out of favor following the September 11 terrorist attacks, highlighting Buffett's strategic investment approach during times of economic uncertainty.
#
#
# Title : Berkshire Hathaway and Key Acquisitions   Rank : 9.0
# Rating Explanation : The impact severity rating is high due to Berkshire Hathaway's significant influence in the global financial markets and its strategic acquisitions.
#
# Summary : The community is centered around Berkshire Hathaway, a multinational conglomerate holding company led by Warren Buffett. Key entities within this community include GEICO, General Re, and other significant acquisitions such as Burlington Northern Santa Fe and National Indemnity. The relationships between these entities highlight Berkshire Hathaway's strategic investment approach and its impact on the financial and insurance sectors.
#
#
# Title : Berkshire Hathaway and Its Strategic Investments   Rank : 9.0
# Rating Explanation : The impact severity rating is high due to Berkshire Hathaway's substantial influence in multiple industries and its role in significant financial transactions.
#
# Summary : The community is centered around Berkshire Hathaway, a multinational conglomerate led by Warren Buffett, known for its diverse portfolio of wholly owned companies and stock investments. Key entities include See's Candies, Goldman Sachs, and several major corporations in which Berkshire Hathaway has made significant investments. The relationships highlight Berkshire Hathaway's strategic acquisitions and investments across various industries, underscoring its influence in the global market.
#
#
# Title : Berkshire Hathaway and Key Acquisitions   Rank : 9.0
# Rating Explanation : The impact severity rating is high due to Berkshire Hathaway's significant influence in the global financial and insurance sectors.
#
# Summary : The community is centered around Berkshire Hathaway, a multinational conglomerate holding company led by Warren Buffett. Key entities include GEICO, General Re, and other significant acquisitions such as Burlington Northern Santa Fe and National Indemnity. The relationships within this community highlight strategic acquisitions and leadership roles that have shaped the company's growth and influence in various industries.
#
#
# Title : Stiritz and Strategic Acquisitions   Rank : 7.5
# Rating Explanation : The impact severity rating is high due to Stiritz's significant influence in the business world through strategic acquisitions and his innovative management approach.
#
# Summary : The community is centered around Stiritz, a business executive known for his innovative and analytical management style, particularly in his leadership of Ralston. Stiritz's approach is characterized by strategic acquisitions and a focus on cash flow, as demonstrated in his dealings with companies like Energizer and Nestlé. His network includes key figures such as Rand Araskog and Pat Mulcahy, and he is noted for his unconventional methods and adaptability.
#
#
# Title : Lehman Brothers Collapse and Liberty Media's Strategic Maneuvers   Rank : 9.0
# Rating Explanation : The impact severity rating is high due to the global financial implications of Lehman Brothers' collapse and the strategic responses by major financial players.
#
# Summary : This community is centered around the collapse of Lehman Brothers in September 2008, a pivotal event that triggered a global financial crisis. Key entities include Lehman Brothers, Liberty Media, and influential figures like John Malone and Warren Buffett. The relationships between these entities highlight strategic financial maneuvers and investments made in response to the crisis, particularly by Liberty Media under John Malone's leadership and Warren Buffett's significant investments.

# %% [markdown]
# ### Community

# %%
community_report_df.iloc[0]
# Out:
# id                                     61a89e0dcd6f439c9ff1bb7e0f72abd4
# human_readable_id                                                    10
# community                                                            10
# level                                                                 3
# parent                                                                8
# children                                                             []
# title                 Berkshire Hathaway and Warren Buffett's Invest...
# summary               The community is centered around Berkshire Hat...
# full_content          # Berkshire Hathaway and Warren Buffett's Inve...
# rank                                                                9.5
# rating_explanation    The impact severity rating is high due to Berk...
# findings              [{'explanation': 'Warren Buffett, as the chair...
# full_content_json     {\n    "title": "Berkshire Hathaway and Warren...
# period                                                       2025-05-02
# size                                                                 10
# Name: 0, dtype: object

# %%
print(f"Title : {community_report_df.iloc[0]["title"]}")
print(f"\nSummary : {community_report_df.iloc[0]["summary"]}")
# Out:
# Title : Berkshire Hathaway and Warren Buffett's Investment Network
#
# Summary : The community is centered around Berkshire Hathaway, a multinational conglomerate led by Warren Buffett, with significant contributions from Charlie Munger. Key entities include major acquisitions such as GEICO, General Re, and Burlington Northern Santa Fe, which highlight Buffett's strategic investment approach. The relationships within this network demonstrate a focus on insurance, transportation, and strategic partnerships, reflecting a diversified investment strategy that has been pivotal in Berkshire Hathaway's growth and influence.

# %%
print(community_report_df.iloc[0]["full_content"])
# Out:
# # Berkshire Hathaway and Warren Buffett's Investment Network
#
# The community is centered around Berkshire Hathaway, a multinational conglomerate led by Warren Buffett, with significant contributions from Charlie Munger. Key entities include major acquisitions such as GEICO, General Re, and Burlington Northern Santa Fe, which highlight Buffett's strategic investment approach. The relationships within this network demonstrate a focus on insurance, transportation, and strategic partnerships, reflecting a diversified investment strategy that has been pivotal in Berkshire Hathaway's growth and influence.
#
# ## Warren Buffett's Strategic Leadership
#
# Warren Buffett, as the chairman and CEO of Berkshire Hathaway, is a central figure in this community. His leadership and investment strategies have been instrumental in shaping the company's direction and success. Buffett's ability to identify and capitalize on investment opportunities, particularly during financial crises, has earned him the nickname 'Oracle of Omaha' [Data: Entities (29)]. His strategic acquisitions, such as GEICO and General Re, demonstrate his focus on long-term value and market influence [Data: Relationships (48, 49)].
#
# ## Charlie Munger's Influence on Investment Strategy
#
# Charlie Munger, the vice chairman of Berkshire Hathaway, has played a crucial role in influencing Warren Buffett's investment strategy. Munger's insights have been pivotal in shifting the company's focus from traditional value investing to prioritizing companies with strong brands and market positions [Data: Entities (30); Relationships (27)]. This strategic shift has allowed Berkshire Hathaway to maintain its competitive edge and continue its growth trajectory.
#
# ## Significant Acquisitions: GEICO and General Re
#
# GEICO and General Re are two significant acquisitions by Berkshire Hathaway that highlight its strategic focus on the insurance sector. GEICO, acquired in 1996, has become a major contributor to the conglomerate's portfolio, reflecting its importance and value [Data: Entities (35); Relationships (48)]. General Re, acquired in 1998 for $22 billion, marked the largest transaction in Berkshire Hathaway's history, underscoring the company's commitment to expanding its insurance operations [Data: Entities (45); Relationships (49)].
#
# ## Diversification through Transportation: Burlington Northern Santa Fe
#
# The acquisition of Burlington Northern Santa Fe in 2010 represents Berkshire Hathaway's strategic diversification into the transportation sector. As the largest railroad in the United States, this acquisition has strengthened the conglomerate's presence in the transportation industry and provided a stable revenue stream [Data: Entities (57); Relationships (55)]. This move aligns with Buffett's strategy of investing in essential infrastructure that supports economic growth.
#
# ## The Role of Insurance Float in Investment Strategy
#
# Warren Buffett's acquisition of National Indemnity in 1967 highlights the strategic use of insurance float in Berkshire Hathaway's investment strategy. The float, which refers to the funds held by insurers before claims are paid, provides a significant source of capital for investment [Data: Entities (58); Relationships (56)]. This approach has allowed Berkshire Hathaway to leverage its insurance operations to fund other strategic investments, contributing to its overall growth and success.

# %% [markdown]
# #### Summary under consideration
# Diversification through Transportation: Burlington Northern Santa Fe
#
# The acquisition of Burlington Northern Santa Fe in 2010 represents Berkshire Hathaway's strategic diversification into the transportation sector. As the largest railroad in the United States, this acquisition has strengthened the conglomerate's presence in the transportation industry and provided a stable revenue stream [Data: Entities (57); Relationships (55)]. This move aligns with Buffett's strategy of investing in essential infrastructure that supports economic growth.

# %%
idx = 57
print(f"Entity : {entity_df.iloc[idx]["title"]}    Type : {entity_df.iloc[idx]["type"]}")
print(f"Description : {entity_df.iloc[idx]["description"]}")
# Out:
# Entity : BURLINGTON NORTHERN SANTA FE    Type : ORGANIZATION
# Description : Burlington Northern Santa Fe is the largest railroad in the United States, acquired by Berkshire Hathaway in 2010

# %%
idx = 55
print(f"Source : {relationships_df.iloc[idx]["source"]}    Target : {relationships_df.iloc[idx]["target"]}    Weight : {relationships_df.iloc[idx]["weight"]}")
print(f"Description : {relationships_df.iloc[idx]["description"]}")
# Out:
# Source : WARREN BUFFETT    Target : BURLINGTON NORTHERN SANTA FE    Weight : 9.0
# Description : Warren Buffett acquired Burlington Northern Santa Fe in 2010

# %% [markdown]
# #### Summary under consideration
#
# Significant Acquisitions: GEICO and General Re
#
# GEICO and General Re are two significant acquisitions by Berkshire Hathaway that highlight its strategic focus on the insurance sector. GEICO, acquired in 1996, has become a major contributor to the conglomerate's portfolio, reflecting its importance and value [Data: Entities (35); Relationships (48)]. General Re, acquired in 1998 for $22 billion, marked the largest transaction in Berkshire Hathaway's history, underscoring the company's commitment to expanding its insurance operations [Data: Entities (45); Relationships (49)].

# %%
idx = 45
print(f"Entity : {entity_df.iloc[idx]["title"]}    Type : {entity_df.iloc[idx]["type"]}")
print(f"Description : {entity_df.iloc[idx]["description"]}")
# Out:
# Entity : GENERAL RE    Type : ORGANIZATION
# Description : General Re is a prominent reinsurer that was acquired by Berkshire Hathaway in 1998. This acquisition was a significant milestone, as it marked the largest transaction in Berkshire Hathaway's history, with a deal valued at $22 billion.

# %%
idx = 49
print(f"Source : {relationships_df.iloc[idx]["source"]}    Target : {relationships_df.iloc[idx]["target"]}    Weight : {relationships_df.iloc[idx]["weight"]}")
print(f"Description : {relationships_df.iloc[idx]["description"]}")
# Out:
# Source : WARREN BUFFETT    Target : GENERAL RE    Weight : 8.0
# Description : Warren Buffett acquired General Re in 1998 for $22 billion

# %% [markdown]
# ### Visualize Graph

# %%
G = nx.DiGraph()

# %%
for _, row in entity_df.iterrows():
    G.add_node(row['title'], type=row['type'], description=row['description'])

# %%
for _, row in relationships_df.iterrows():
    G.add_edge(row['source'], row['target'], description=row['description'], strength=row['weight'])

# %%
plt.figure(figsize=(25, 25))
pos = nx.spring_layout(G, k=0.5)

node_colors = ['lightblue' if G.nodes[n]['type'] == 'user' else 'lightgreen' for n in G.nodes]
nx.draw_networkx_nodes(G, pos, node_size=500, node_color=node_colors)

nx.draw_networkx_edges(G, pos, arrowstyle='->', arrowsize=10)

nx.draw_networkx_labels(G, pos, font_size=12)

edge_labels = {(u, v): d['strength'] for u, v, d in G.edges(data=True)}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')

plt.title("Knowledge Graph Visualization")
plt.axis('off')
plt.tight_layout()
plt.show()
