# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

from langchain_openai import ChatOpenAI
from langchain_text_splitters import TokenTextSplitter
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
main_path = "/home/aswath/Projects/deep_learning/backup_brain/test_4/"

# %% [markdown]
# ### Demonstration of Knowledge Graph Creation

# %%
input_path = main_path + "input/tca_chat.txt"

# %%
with open(input_path, 'r') as file:
    content = file.read()

text_splitter = TokenTextSplitter(chunk_size=2000, chunk_overlap=100)
texts = text_splitter.split_text(content)

# %%
prompt_template = """
-Goal-
Given a text document about unconventional CEOs and their business strategies, identify all significant entities and relationships related to management philosophy, operational models, and organizational behavior. Also identify communities or clusters of similarly acting individuals or organizations if applicable.

-Steps-
1. Identify all entities. For each identified entity, extract the following information:
- entity_name: Name of the entity, capitalized
- entity_type: One of the following types: [CEO, business strategy, capital allocation approach, acquisition strategy, management style, organizational structure, performance metric, leadership trait, company, investment philosophy, decentralization approach, financial policy, operational efficiency, cultural value, peer group]
- entity_description: Comprehensive description of the entity’s attributes, behaviors, or significance
Format each entity as ("entity"{{tuple_delimiter}}<entity_name>{{tuple_delimiter}}<entity_type>{{tuple_delimiter}}<entity_description>)

2. From the entities identified in step 1, identify all pairs of (source_entity, target_entity) that are *clearly related* to each other.
For each pair of related entities, extract the following information:
- source_entity: name of the source entity, as identified in step 1
- target_entity: name of the target entity, as identified in step 1
- relationship_description: explanation as to why you think the source entity and the target entity are related to each other
- relationship_strength: an integer score between 1 to 10, indicating strength of the relationship between the source entity and target entity
Format each relationship as ("relationship"{{tuple_delimiter}}<source_entity>{{tuple_delimiter}}<target_entity>{{tuple_delimiter}}<relationship_description>{{tuple_delimiter}}<relationship_strength>)

3. Return output in English as a single list of all the entities and relationships identified in steps 1 and 2. Use **{{record_delimiter}}** as the list delimiter.

4. If you have to translate into English, just translate the descriptions, nothing else!

5. When finished, output {{completion_delimiter}}.

-Examples-
######################

entity_types: [CEO, business strategy, capital allocation approach, acquisition strategy, management style, organizational structure, performance metric, leadership trait, company, investment philosophy, decentralization approach, financial policy, operational efficiency, cultural value, peer group]
text: {input_text}
######################
output:
"""

# %%
llm = ChatOpenAI(temperature=0.0, model="gpt-4o", api_key= "dummy_val")

prompt = ChatPromptTemplate.from_template(prompt_template)
chain = prompt | llm | StrOutputParser()

# %%
response = chain.invoke({"input_text": content[:10000]})

# %%
print(response)
# Out:
# ("entity" | "John Templeton" | "CEO" | "John Templeton is known for his quote about producing superior performance by doing something different, highlighting his unconventional approach to business leadership.") **{record_delimiter}** ("entity" | "Henry Singleton" | "CEO" | "Henry Singleton was a CEO known for his unconventional management style and superior market performance compared to peers like Jack Welch.") **{record_delimiter}** ("entity" | "Jack Welch" | "CEO" | "Jack Welch is a well-known CEO, often portrayed as a charismatic, action-oriented leader, and a benchmark for market performance.") **{record_delimiter}** ("entity" | "Warren Buffett" | "CEO" | "Warren Buffett is a renowned CEO who identified the 'institutional imperative' as a force that compels CEOs to imitate their peers.") **{record_delimiter}** ("entity" | "Teledyne" | "company" | "Teledyne is a company known for its exceptional market performance under unconventional leadership.") **{record_delimiter}** ("entity" | "Singletonville" | "peer group" | "Singletonville refers to a group of CEOs who share unconventional management styles and superior performance.") **{record_delimiter}** ("entity" | "Billy Beane" | "CEO" | "Billy Beane is known for his unconventional, analytical approach to managing the Oakland A's baseball team, leading to exceptional performance.") **{record_delimiter}** ("entity" | "Oakland A's" | "company" | "The Oakland A's is a baseball team managed by Billy Beane, known for its success despite financial constraints.") **{record_delimiter}** ("entity" | "institutional imperative" | "management philosophy" | "The institutional imperative is a concept identified by Warren Buffett, describing the tendency of CEOs to imitate their peers.") **{record_delimiter}** ("entity" | "decentralization approach" | "decentralization approach" | "A management approach where organizations are run in a highly decentralized manner, allowing for independent decision-making.") **{record_delimiter}** ("entity" | "cash flow–based metrics" | "performance metric" | "Unusual financial metrics focused on cash flow, used by unconventional CEOs to measure performance.") **{record_delimiter}** ("entity" | "General Cinema's Dick Smith" | "CEO" | "Dick Smith was a CEO known for his patient investment strategy, waiting for compelling opportunities.") **{record_delimiter}** ("relationship" | "John Templeton" | "Henry Singleton" | "Both are noted for their unconventional approaches to achieving superior performance." | 7) **{record_delimiter}** ("relationship" | "Henry Singleton" | "Singletonville" | "Henry Singleton is a part of the group of unconventional CEOs referred to as Singletonville." | 8) **{record_delimiter}** ("relationship" | "Jack Welch" | "Henry Singleton" | "Henry Singleton's performance was compared to Jack Welch's, highlighting Singleton's superior market performance." | 6) **{record_delimiter}** ("relationship" | "Warren Buffett" | "institutional imperative" | "Warren Buffett identified the institutional imperative as a key concept in CEO behavior." | 9) **{record_delimiter}** ("relationship" | "Billy Beane" | "Oakland A's" | "Billy Beane's management of the Oakland A's is a prime example of his unconventional approach." | 10) **{record_delimiter}** ("relationship" | "decentralization approach" | "Singletonville" | "The CEOs in Singletonville employed a highly decentralized approach in their management." | 8) **{record_delimiter}** ("relationship" | "cash flow–based metrics" | "Singletonville" | "The CEOs in Singletonville used cash flow–based metrics to measure performance." | 8) **{record_delimiter}** ("relationship" | "General Cinema's Dick Smith" | "Singletonville" | "Dick Smith's patient investment strategy aligns with the unconventional approaches of Singletonville CEOs." | 7) **{completion_delimiter}**

# %% [markdown]
# ### Analysing Created Knowledge Graph

# %%
entities_path = main_path + "output/entities.parquet"
communities_path = main_path + "output/communities.parquet"
community_reports_path = main_path + "output/community_reports.parquet"
documents_path = main_path + "output/documents.parquet"
relationships_path = "output/relationships.parquet"

entity_df = pd.read_parquet(entities_path)
community_df = pd.read_parquet(communities_path)
community_report_df = pd.read_parquet(community_reports_path)
documents_df = pd.read_parquet(documents_path)
relationships_df = pd.read_parquet(relationships_path)

# %% [markdown]
# ### Entity

# %%
entity_df.head()
# Out:
#                                      id  human_readable_id              title  \
# 0  0a642f4c-74bb-443e-b3c0-93a841d6f561                  0         MUTHUKUMAR
# 1  30e51683-d86a-4a89-af1e-7fe5c46e8dc5                  1  ZEE ENTERTAINMENT
# 2  108dbbcd-00c8-468a-91d3-bbb0f86e6b8a                  2            MOHAN G
# 3  f034ac23-c0a0-4749-8dd0-d6038fac338d                  3       DIVAKAR ANNA
# 4  8089fdb8-bf41-42a8-b4de-e988da5dcd7c                  4                GVM
#
#            type                                        description  \
# 0        PERSON  Muthukumar is the director of Ayali, recognize...
# 1  ORGANIZATION  Zee Entertainment is a media company that inve...
# 2        PERSON  Mohan G is a reviewer mentioned in the convers...
# 3        PERSON  Divakar Anna is another reviewer mentioned, po...
# 4        PERSON  GVM is a person whose birthday was noted in th...
#
#                                        text_unit_ids  frequency  degree    x  \
# 0  [b198a1b3deb8f7fb3c5da37c4f98f1c7aa52663fb162f...          1       2  0.0
# 1  [b198a1b3deb8f7fb3c5da37c4f98f1c7aa52663fb162f...          1       2  0.0
# 2  [b198a1b3deb8f7fb3c5da37c4f98f1c7aa52663fb162f...          1       0  NaN
# 3  [b198a1b3deb8f7fb3c5da37c4f98f1c7aa52663fb162f...          1       0  NaN
# 4  [b198a1b3deb8f7fb3c5da37c4f98f1c7aa52663fb162f...          1       0  NaN
#
#      y
# 0  0.0
# 1  0.0
# 2  NaN
# 3  NaN
# 4  NaN

# %%
for i in range(entity_df.shape[0]):
    print(f"\n\nEntity : {entity_df.iloc[i]["title"]}    Type : {entity_df.iloc[i]["type"]}")
    print(f"Description : {entity_df.iloc[i]["description"]}")
# Out:
# Entity : MUTHUKUMAR    Type : PERSON
# Description : Muthukumar is the director of Ayali, recognized for his talent in the film industry
#
#
# Entity : ZEE ENTERTAINMENT    Type : ORGANIZATION
# Description : Zee Entertainment is a media company that invested in the production of Ayali despite financial losses
#
#
# Entity : MOHAN G    Type : PERSON
# Description : Mohan G is a reviewer mentioned in the conversation, possibly providing reviews on media content
#
#
# Entity : DIVAKAR ANNA    Type : PERSON
# Description : Divakar Anna is another reviewer mentioned, possibly providing reviews on media content
#
#
# Entity : GVM    Type : PERSON
# Description : GVM is a person whose birthday was noted in the conversation, possibly a notable figure among the group
#
#
# Entity : ADARSH    Type : PERSON
# Description : Adarsh is an active participant in the conversation, engaging with others by sharing media links and commenting on various topics. Notably, Adarsh has been involved in discussions regarding Ajith Kumar's situation, contributing insights and opinions to the ongoing dialogue. Through these interactions, Adarsh demonstrates a keen interest in the subject matter and a willingness to engage with the community, fostering a dynamic and interactive environment.
#
#
# Entity : MUTHU MANIMARAN    Type : PERSON
# Description : Muthu Manimaran is a participant in the conversation, sharing media links and engaging with others
#
#
# Entity : DINESH ANNA IIT SENIOR    Type : PERSON
# Description : Dinesh Anna IIT Senior is a participant in the conversation, possibly a senior member of the group
#
#
# Entity : DARSHAN    Type : PERSON
# Description : Darshan is a participant in the conversation, contributing to discussions about inside jokes
#
#
# Entity : SARATH    Type : PERSON
# Description : Sarath is a participant in the conversation, engaging in discussions about events that occurred
#
#
# Entity : DHARUN AEROSPACE    Type : PERSON
# Description : Dharun Aerospace is a participant in the conversation, adding new members to the group
#
#
# Entity : KARTHI BRO IITB AERO    Type : PERSON
# Description : Karthi Bro IITB Aero is a new member added to the group, possibly associated with aerospace studies
#
#
# Entity : PRAVEEN TAMIL SENIOR    Type : PERSON
# Description : Praveen Tamil Senior is a participant in the conversation, sharing media links and engaging with others
#
#
# Entity : AKSHAY AERO JUNIOR    Type : PERSON
# Description : Akshay Aero Junior is a participant in the conversation, questioning the group's actions
#
#
# Entity : AYALI    Type :
# Description :
#
#
# Entity : AJITH KUMAR    Type : PERSON
# Description : Ajith Kumar is a Tamil film actor who was reportedly mobbed at Chennai airport and hospitalized after suffering a leg injury
#
#
# Entity : CHENNAI    Type : GEO
# Description : Chennai is a city in India where Ajith Kumar was reportedly mobbed at the airport
#
#
# Entity : THARUN ESED JUNIOR    Type : PERSON
# Description : Tharun ESED Junior is a participant in the conversation, responding to others
#
#
# Entity : INDIAN EXPRESS    Type : ORGANIZATION
# Description : Indian Express is a news organization that published an article about Ajith Kumar's incident
#
#
# Entity : YOUTUBE    Type : ORGANIZATION
# Description : YouTube is a video-sharing platform where a video related to the conversation was shared
#
#
# Entity : ASWATH    Type : PERSON
# Description : Aswath is an active participant in a multifaceted conversation that covers a range of topics. He engages in discussions about cricket players and their skills, showcasing his interest in sports. Additionally, Aswath contributes to conversations about ownership of products and food preferences, indicating a diverse set of interests and a willingness to explore various subjects. In a more personal context, Aswath is involved in a dialogue with Vinu Rakav, where they discuss his future plans and college life, suggesting that he is at a stage where education and career planning are significant aspects of his life. Furthermore, Aswath is preparing for exams next week, highlighting his current focus on academic responsibilities. Overall, Aswath is depicted as a well-rounded individual who is engaged in both personal and broader discussions, balancing his interests and responsibilities effectively.
#
#
# Entity : VINU RAKAV IITB JUNIOR    Type : PERSON
# Description : Vinu Rakav IITB Junior is an individual actively participating in conversations that cover a diverse range of topics. As a likely student or alumnus of the prestigious Indian Institute of Technology Bombay (IITB), Vinu Rakav brings a unique perspective to discussions. His involvement spans various subjects, including the skills of cricket players, ownership of products, and food preferences. This breadth of interests suggests that Vinu Rakav is not only knowledgeable about sports but also engaged in broader lifestyle and consumer topics. His participation in these conversations highlights his ability to contribute meaningfully to discussions on both specialized and general subjects.
#
#
# Entity : SACHIN    Type : PERSON
# Description : Sachin is mentioned as a technically good batsman with a range of shots
#
#
# Entity : KOHLI    Type : PERSON
# Description : Kohli is mentioned as a technically good batsman with a range of shots and is noted for having the highest average in a list
#
#
# Entity : DRAVID    Type : PERSON
# Description : Dravid is mentioned as a technically good batsman with a range of shots
#
#
# Entity : SANGAKKARA    Type : PERSON
# Description : Sangakkara is mentioned as a technically good batsman with a range of shots
#
#
# Entity : KANE    Type : PERSON
# Description : Kane is mentioned as a technically good batsman with a range of shots
#
#
# Entity : PONTING    Type : PERSON
# Description : Ponting is mentioned in the context of being compared to Kohli
#
#
# Entity : ROHIT    Type : PERSON
# Description : Rohit is mentioned as a notable cricket player from India
#
#
# Entity : DE VILLIERS    Type : PERSON
# Description : De Villiers is mentioned in the context of having a high average in a list of cricket players
#
#
# Entity : TEN DOESCHATE    Type : PERSON
# Description : Ten Doeschate is mentioned as having the highest average in a list of cricket players
#
#
# Entity : OXFORD UNIVERSITY    Type : ORGANIZATION
# Description : Oxford University is mentioned as a place where Aswath claims to have studied a course
#
#
# Entity : INSTAGRAM    Type : ORGANIZATION
# Description : Instagram is mentioned as a platform where a link was shared
#
#
# Entity : SUNNXT    Type : ORGANIZATION
# Description : SunNXT is mentioned in the context of an Instagram post
#
#
# Entity : THALA    Type :
# Description :
#
#
# Entity : VINU RAKAV    Type : PERSON
# Description : Vinu Rakav is a junior at the Indian Institute of Technology Bombay (IITB). He is currently engaged in discussions about his plans following the completion of his exams and his subsequent departure from the campus. As an active participant in these conversations, Vinu is identified as an IITB junior, indicating his current academic standing and involvement in the campus community.
#
#
# Entity : FAF    Type : PERSON
# Description : Faf is a cricketer mentioned in the context of scoring a century despite an injury
#
#
# Entity : MAXWELL    Type : PERSON
# Description : Maxwell is a cricketer mentioned in the context of scoring 200 runs while on cramps
#
#
# Entity : SAI    Type : PERSON
# Description : Sai is a cricketer mentioned in the context of getting out in a match
#
#
# Entity : AFGHANISTAN    Type : GEO
# Description : Afghanistan is mentioned in the context of a cricket match
#
#
# Entity : WORLD CUP 2023    Type : EVENT
# Description : The 2023 Cricket World Cup held in India
#
#
# Entity : IPL    Type : EVENT
# Description : The Indian Premier League, a high-scoring cricket tournament
#
#
# Entity : CHEPAUK    Type : GEO
# Description : Chepauk is a cricket stadium mentioned in the context of spin-friendly conditions
#
#
# Entity : GT    Type : ORGANIZATION
# Description : GT is a cricket team mentioned in the context of missing a no ball by 1 cm
#
#
# Entity : CHENNAI SUPER KINGS    Type : ORGANIZATION
# Description : Chennai Super Kings is a cricket team mentioned in the context of merchandise and fan support
#
#
# Entity : INDIA    Type : GEO
# Description : India is the host country for the 2023 Cricket World Cup
#
#
# Entity : CSK    Type : ORGANIZATION
# Description : CSK, or Chennai Super Kings, is a cricket team mentioned in the context of fan support and merchandise
#
#
# Entity : DUBE    Type :
# Description :
#
#
# Entity : MR BEAST    Type : PERSON
# Description : Mr Beast is a well-known internet personality mentioned in the context of product ownership
#
#
# Entity : LOGAN PAUL    Type : PERSON
# Description : Logan Paul is a well-known internet personality mentioned in the context of product ownership
#
#
# Entity : KSI    Type : PERSON
# Description : KSI is a co-owner of the product Prime, mentioned in the conversation
#
#
# Entity : PRIME    Type : ORGANIZATION
# Description : Prime is a product co-owned by Logan Paul and KSI, mentioned in the conversation
#
#
# Entity : FEASTABLES    Type :
# Description :
#
#
# Entity : IITB    Type : ORGANIZATION
# Description : Indian Institute of Technology Bombay, where Vinu Rakav is a junior student
#
#
# Entity : THAMIZHA GROUP    Type : ORGANIZATION
# Description : A group mentioned by Vinu Rakav where messages are taken seriously
#
#
# Entity : TCA    Type : ORGANIZATION
# Description : A group mentioned by Vinu Rakav where messages are often ignored
#
#
# Entity : BANGALORE    Type :
# Description :
#
#
# Entity : AKSHAY    Type : PERSON
# Description : Akshay is a person mentioned as potentially accompanying Vinu Rakav in Bangalore
#
#
# Entity : VENKATESH    Type : PERSON
# Description : Venkatesh is a person mentioned as potentially accompanying Vinu Rakav in Bangalore
#
#
# Entity : ENDSEMS    Type : EVENT
# Description : Endsems refers to the end-of-semester exams that Aswath is preparing for

# %% [markdown]
# ### Relationships

# %%
relationships_df.head()
# Out:
#                                      id  human_readable_id             source  \
# 0  b0cb8e80-28dd-4fde-92d4-7eb52659f60e                  0         MUTHUKUMAR
# 1  db92ec2e-e3a7-48dc-944f-68211494b7d2                  1         MUTHUKUMAR
# 2  b553522a-efd6-4355-a9fd-7c8d719c71fa                  2  ZEE ENTERTAINMENT
# 3  791e21ad-8348-4248-9b47-e77063610cab                  3             ADARSH
# 4  a6346e1e-8542-449f-978b-296dfa2c8f26                  4   DHARUN AEROSPACE
#
#                  target                                        description  \
# 0     ZEE ENTERTAINMENT  Muthukumar directed Ayali, which was produced ...
# 1                 AYALI  Muthukumar is the director of Ayali, a film me...
# 2                 AYALI  Zee Entertainment invested in the production o...
# 3       MUTHU MANIMARAN  Adarsh and Muthu Manimaran are both active par...
# 4  KARTHI BRO IITB AERO  Dharun Aerospace added Karthi Bro IITB Aero to...
#
#    weight  combined_degree                                      text_unit_ids
# 0     1.0                4  [b198a1b3deb8f7fb3c5da37c4f98f1c7aa52663fb162f...
# 1     8.0                4  [b198a1b3deb8f7fb3c5da37c4f98f1c7aa52663fb162f...
# 2     1.0                4  [b198a1b3deb8f7fb3c5da37c4f98f1c7aa52663fb162f...
# 3     5.0                6  [b198a1b3deb8f7fb3c5da37c4f98f1c7aa52663fb162f...
# 4     7.0                2  [b198a1b3deb8f7fb3c5da37c4f98f1c7aa52663fb162f...

# %%
for i in range(relationships_df.shape[0]):
    print(f"\n\nSource : {relationships_df.iloc[i]["source"]}    Target : {relationships_df.iloc[i]["target"]}    Weight : {relationships_df.iloc[i]["weight"]}")
    print(f"Description : {relationships_df.iloc[i]["description"]}")
# Out:
# Source : MUTHUKUMAR    Target : ZEE ENTERTAINMENT    Weight : 1.0
# Description : Muthukumar directed Ayali, which was produced by Zee Entertainment
#
#
# Source : MUTHUKUMAR    Target : AYALI    Weight : 8.0
# Description : Muthukumar is the director of Ayali, a film mentioned in the conversation
#
#
# Source : ZEE ENTERTAINMENT    Target : AYALI    Weight : 1.0
# Description : Zee Entertainment invested in the production of Ayali
#
#
# Source : ADARSH    Target : MUTHU MANIMARAN    Weight : 5.0
# Description : Adarsh and Muthu Manimaran are both active participants in the conversation, sharing media links and engaging with each other
#
#
# Source : DHARUN AEROSPACE    Target : KARTHI BRO IITB AERO    Weight : 7.0
# Description : Dharun Aerospace added Karthi Bro IITB Aero to the group
#
#
# Source : AJITH KUMAR    Target : CHENNAI    Weight : 1.0
# Description : Ajith Kumar was mobbed at the Chennai airport
#
#
# Source : AJITH KUMAR    Target : MUTHU MANIMARAN    Weight : 5.0
# Description : Muthu Manimaran shared a link about Ajith Kumar's incident
#
#
# Source : AJITH KUMAR    Target : ADARSH    Weight : 4.0
# Description : Adarsh commented on Ajith Kumar's situation
#
#
# Source : AJITH KUMAR    Target : INDIAN EXPRESS    Weight : 6.0
# Description : Indian Express published an article about Ajith Kumar's incident
#
#
# Source : THARUN ESED JUNIOR    Target : MUTHU MANIMARAN    Weight : 3.0
# Description : Tharun ESED Junior responded to Muthu Manimaran in the conversation
#
#
# Source : YOUTUBE    Target : MUTHU MANIMARAN    Weight : 1.0
# Description : Muthu Manimaran shared a YouTube link in the conversation
#
#
# Source : ASWATH    Target : VINU RAKAV IITB JUNIOR    Weight : 7.0
# Description : Aswath and Vinu Rakav IITB Junior are engaged in a conversation about cricket players
#
#
# Source : ASWATH    Target : OXFORD UNIVERSITY    Weight : 1.0
# Description : Aswath claims to have studied a course at Oxford University
#
#
# Source : ASWATH    Target : THALA    Weight : 3.0
# Description : Aswath mentions Thala in the context of cricket
#
#
# Source : ASWATH    Target : INSTAGRAM    Weight : 2.0
# Description : Aswath shares a link to an Instagram post
#
#
# Source : KOHLI    Target : DE VILLIERS    Weight : 5.0
# Description : Kohli and De Villiers are compared in terms of their averages in a list
#
#
# Source : KOHLI    Target : TEN DOESCHATE    Weight : 5.0
# Description : Kohli and Ten Doeschate are compared in terms of their averages in a list
#
#
# Source : INSTAGRAM    Target : SUNNXT    Weight : 1.0
# Description : SunNXT is mentioned in an Instagram post
#
#
# Source : VINU RAKAV    Target : ASWATH    Weight : 15.0
# Description : Vinu Rakav and Aswath are engaged in a conversation where they are discussing Vinu's plans and experiences. Both individuals are active participants in this dialogue, contributing to a shared exchange of ideas and insights. The interaction highlights their collaborative engagement, focusing on Vinu's personal and professional journey.
#
#
# Source : VINU RAKAV    Target : DUBE    Weight : 4.0
# Description : Dube is mentioned in a conversation by Vinu Rakav
#
#
# Source : FAF    Target : WORLD CUP 2023    Weight : 5.0
# Description : Faf is mentioned in the context of a performance during the World Cup 2023
#
#
# Source : MAXWELL    Target : WORLD CUP 2023    Weight : 5.0
# Description : Maxwell is mentioned in the context of a performance during the World Cup 2023
#
#
# Source : SAI    Target : WORLD CUP 2023    Weight : 5.0
# Description : Sai is mentioned in the context of a performance during the World Cup 2023
#
#
# Source : AFGHANISTAN    Target : WORLD CUP 2023    Weight : 5.0
# Description : Afghanistan is mentioned in the context of a match during the World Cup 2023
#
#
# Source : WORLD CUP 2023    Target : INDIA    Weight : 9.0
# Description : India is the host country for the World Cup 2023
#
#
# Source : IPL    Target : CHEPAUK    Weight : 6.0
# Description : Chepauk is mentioned as a venue for IPL matches
#
#
# Source : IPL    Target : GT    Weight : 6.0
# Description : GT is a team participating in the IPL
#
#
# Source : IPL    Target : CHENNAI SUPER KINGS    Weight : 1.0
# Description : Chennai Super Kings is a team participating in the IPL
#
#
# Source : CHENNAI SUPER KINGS    Target : CSK    Weight : 1.0
# Description : CSK is an abbreviation for Chennai Super Kings
#
#
# Source : VINU RAKAV IITB JUNIOR    Target : ASWATH    Weight : 1.0
# Description : Vinu Rakav IITB Junior and Aswath are engaged in a conversation discussing various topics
#
#
# Source : VINU RAKAV IITB JUNIOR    Target : MR BEAST    Weight : 6.0
# Description : Vinu Rakav IITB Junior mentions Mr Beast in the context of product ownership
#
#
# Source : VINU RAKAV IITB JUNIOR    Target : LOGAN PAUL    Weight : 6.0
# Description : Vinu Rakav IITB Junior mentions Logan Paul in the context of product ownership
#
#
# Source : VINU RAKAV IITB JUNIOR    Target : KSI    Weight : 6.0
# Description : Vinu Rakav IITB Junior mentions KSI as a co-owner of Prime
#
#
# Source : ASWATH    Target : MR BEAST    Weight : 5.0
# Description : Aswath expresses a lack of interest in Mr Beast
#
#
# Source : ASWATH    Target : LOGAN PAUL    Weight : 1.0
# Description : Aswath expresses a lack of interest in Logan Paul
#
#
# Source : MR BEAST    Target : FEASTABLES    Weight : 7.0
# Description : Mr Beast is associated with the product Feastables
#
#
# Source : LOGAN PAUL    Target : PRIME    Weight : 8.0
# Description : Logan Paul is a co-owner of the product Prime
#
#
# Source : KSI    Target : PRIME    Weight : 8.0
# Description : KSI is a co-owner of the product Prime
#
#
# Source : VINU RAKAV    Target : IITB    Weight : 9.0
# Description : Vinu Rakav is a junior student at IITB
#
#
# Source : VINU RAKAV    Target : THAMIZHA GROUP    Weight : 5.0
# Description : Vinu Rakav mentions that messages in Thamizha Group are taken seriously
#
#
# Source : VINU RAKAV    Target : TCA    Weight : 5.0
# Description : Vinu Rakav mentions that messages in TCA are often ignored
#
#
# Source : VINU RAKAV    Target : BANGALORE    Weight : 1.0
# Description : Vinu Rakav mentions that he will be in Bangalore
#
#
# Source : VINU RAKAV IITB JUNIOR    Target : BANGALORE    Weight : 7.0
# Description : Vinu Rakav plans to go to Bangalore and search for accommodation
#
#
# Source : VINU RAKAV IITB JUNIOR    Target : AKSHAY    Weight : 5.0
# Description : Akshay is mentioned as someone who might be with Vinu Rakav in Bangalore
#
#
# Source : VINU RAKAV IITB JUNIOR    Target : VENKATESH    Weight : 1.0
# Description : Venkatesh is mentioned as someone who might be with Vinu Rakav in Bangalore
#
#
# Source : ASWATH    Target : ENDSEMS    Weight : 8.0
# Description : Aswath is preparing for the end-of-semester exams
#
#
# Source : ASWATH    Target : INDIA    Weight : 1.0
# Description : Aswath plans to visit India in July

# %% [markdown]
# ### Communities

# %%
community_report_df.head()
# Out:
#                                  id  human_readable_id  community  level  \
# 0  bd280810a9e145cfa3b86997b5cf1fb1                  4          4      1
# 1  df3ece279726491288dd8550bc36f430                  5          5      1
# 2  9ec0813cf111469590b25c0576b052ee                  0          0      0
# 3  bf64425110b34ea8b1c988cbb9896d92                  1          1      0
# 4  2b00028d61ae48109075eef24a0e69c5                  2          2      0
#
#    parent children                                              title  \
# 0       2       []           Aswath's Academic and Social Engagements
# 1       2       []                Vinu Rakav and IIT Bombay Community
# 2      -1       []                            World Cup 2023 in India
# 3      -1       []      Vinu Rakav IITB Junior and Associated Network
# 4      -1   [4, 5]  Aswath and Vinu Rakav's Academic and Social Ne...
#
#                                              summary  \
# 0  The community centers around Aswath, who is ac...
# 1  The community centers around Vinu Rakav, a jun...
# 2  The community centers around the 2023 Cricket ...
# 3  The community centers around Vinu Rakav IITB J...
# 4  The community centers around Aswath and Vinu R...
#
#                                         full_content  rank  \
# 0  # Aswath's Academic and Social Engagements\n\n...   3.5
# 1  # Vinu Rakav and IIT Bombay Community\n\nThe c...   3.5
# 2  # World Cup 2023 in India\n\nThe community cen...   8.5
# 3  # Vinu Rakav IITB Junior and Associated Networ...   4.5
# 4  # Aswath and Vinu Rakav's Academic and Social ...   4.5
#
#                                   rating_explanation  \
# 0  The impact severity rating is low due to the p...
# 1  The impact severity rating is low due to the p...
# 2  The impact severity rating is high due to the ...
# 3  The impact severity rating is moderate due to ...
# 4  The impact severity rating is moderate due to ...
#
#                                             findings  \
# 0  [{'explanation': 'Aswath is depicted as an ind...
# 1  [{'explanation': 'Vinu Rakav is identified as ...
# 2  [{'explanation': 'India is the host country fo...
# 3  [{'explanation': 'Vinu Rakav IITB Junior is a ...
# 4  [{'explanation': 'Aswath is depicted as a well...
#
#                                    full_content_json      period  size
# 0  {\n    "title": "Aswath's Academic and Social ...  2025-05-05     6
# 1  {\n    "title": "Vinu Rakav and IIT Bombay Com...  2025-05-05     5
# 2  {\n    "title": "World Cup 2023 in India",\n  ...  2025-05-05     6
# 3  {\n    "title": "Vinu Rakav IITB Junior and As...  2025-05-05     7
# 4  {\n    "title": "Aswath and Vinu Rakav's Acade...  2025-05-05    11

# %%
for i in range(community_report_df.shape[0]):
    print(f"\n\nTitle : {community_report_df.iloc[i]["title"]}   Rank : {community_report_df.iloc[i]["rank"]}")
    print(f"Rating Explanation : {community_report_df.iloc[i]["rating_explanation"]}")
    print(f"\nSummary : {community_report_df.iloc[i]["summary"]}")
# Out:
# Title : Aswath's Academic and Social Engagements   Rank : 3.5
# Rating Explanation : The impact severity rating is low due to the personal and academic nature of the community's activities, which have limited broader implications.
#
# Summary : The community centers around Aswath, who is actively engaged in a variety of discussions ranging from sports to academic pursuits. Aswath's connections include a claim of studying at Oxford University, preparing for end-of-semester exams, and engaging in social media interactions. The community reflects a blend of personal interests and academic responsibilities, with Aswath as the focal point.
#
#
# Title : Vinu Rakav and IIT Bombay Community   Rank : 3.5
# Rating Explanation : The impact severity rating is low due to the primarily personal and academic nature of the interactions within this community.
#
# Summary : The community centers around Vinu Rakav, a junior at the Indian Institute of Technology Bombay (IITB), and his interactions with various entities including Aswath, Dube, and groups like Thamizha and TCA. Vinu's discussions about his future plans and the dynamics within these groups highlight the social and academic environment at IITB.
#
#
# Title : World Cup 2023 in India   Rank : 8.5
# Rating Explanation : The impact severity rating is high due to the global significance of the World Cup and the notable performances by key players.
#
# Summary : The community centers around the 2023 Cricket World Cup hosted by India, featuring key performances by cricketers such as Faf, Maxwell, and Sai. Afghanistan is also mentioned in the context of a match during the tournament. The relationships between these entities highlight the significance of the event and the notable performances that have occurred.
#
#
# Title : Vinu Rakav IITB Junior and Associated Network   Rank : 4.5
# Rating Explanation : The impact severity rating is moderate due to the community's focus on personal interests and consumer products, which have limited broader societal impact.
#
# Summary : The community centers around Vinu Rakav IITB Junior, an individual with diverse interests ranging from sports to lifestyle topics. He is connected to various individuals and entities, including potential companions in Bangalore and discussions involving well-known internet personalities like Logan Paul and KSI. The network also includes the product Prime, co-owned by Logan Paul and KSI, highlighting a blend of personal and commercial interests.
#
#
# Title : Aswath and Vinu Rakav's Academic and Social Network   Rank : 4.5
# Rating Explanation : The impact severity rating is moderate due to the community's focus on academic and personal development, with limited broader societal impact.
#
# Summary : The community centers around Aswath and Vinu Rakav, two individuals engaged in a multifaceted dialogue encompassing academic, personal, and social topics. Aswath is involved in discussions about cricket, product ownership, and food preferences, while also preparing for exams. Vinu Rakav, a junior at IIT Bombay, is focused on his academic journey and future plans. Their interactions highlight a blend of academic responsibilities and social engagements, with connections to institutions like Oxford University and IIT Bombay, and platforms like Instagram.
#
#
# Title : Mr Beast and Feastables   Rank : 6.5
# Rating Explanation : The impact severity rating is moderate to high due to Mr Beast's significant influence and reach as an internet personality, which can substantially affect the market presence of Feastables.
#
# Summary : The community centers around Mr Beast, a prominent internet personality, and his association with the product Feastables. The relationship between Mr Beast and Feastables is the primary connection within this community, highlighting Mr Beast's influence in product ownership and marketing.

# %% [markdown]
# ### Community

# %%
community_report_df.iloc[0]
# Out:
# id                                     bd280810a9e145cfa3b86997b5cf1fb1
# human_readable_id                                                     4
# community                                                             4
# level                                                                 1
# parent                                                                2
# children                                                             []
# title                          Aswath's Academic and Social Engagements
# summary               The community centers around Aswath, who is ac...
# full_content          # Aswath's Academic and Social Engagements\n\n...
# rank                                                                3.5
# rating_explanation    The impact severity rating is low due to the p...
# findings              [{'explanation': 'Aswath is depicted as an ind...
# full_content_json     {\n    "title": "Aswath's Academic and Social ...
# period                                                       2025-05-05
# size                                                                  6
# Name: 0, dtype: object

# %%
print(f"Title : {community_report_df.iloc[0]["title"]}")
print(f"\nSummary : {community_report_df.iloc[0]["summary"]}")
# Out:
# Title : Aswath's Academic and Social Engagements
#
# Summary : The community centers around Aswath, who is actively engaged in a variety of discussions ranging from sports to academic pursuits. Aswath's connections include a claim of studying at Oxford University, preparing for end-of-semester exams, and engaging in social media interactions. The community reflects a blend of personal interests and academic responsibilities, with Aswath as the focal point.

# %%
print(community_report_df.iloc[0]["full_content"])
# Out:
# # Aswath's Academic and Social Engagements
#
# The community centers around Aswath, who is actively engaged in a variety of discussions ranging from sports to academic pursuits. Aswath's connections include a claim of studying at Oxford University, preparing for end-of-semester exams, and engaging in social media interactions. The community reflects a blend of personal interests and academic responsibilities, with Aswath as the focal point.
#
# ## Aswath's Diverse Interests
#
# Aswath is depicted as an individual with a wide range of interests, engaging in conversations about cricket, product ownership, and food preferences. This diversity in interests suggests a well-rounded personality that is open to exploring various subjects. His involvement in discussions about cricket, particularly mentioning Thala, indicates a passion for sports [Data: Entities (20); Relationships (13)].
#
# ## Academic Focus and Exam Preparation
#
# A significant aspect of Aswath's current activities is his preparation for end-of-semester exams, known as Endsems. This highlights his focus on academic responsibilities and suggests that he is at a critical stage in his educational journey. The emphasis on exam preparation indicates a prioritization of academic success in his life [Data: Entities (20, 59); Relationships (45)].
#
# ## Claim of Studying at Oxford University
#
# Aswath claims to have studied a course at Oxford University, which adds an element of prestige to his academic background. This claim, whether verified or not, reflects an aspiration towards high academic standards and could influence perceptions of his educational credentials [Data: Entities (20, 31); Relationships (12)].
#
# ## Social Media Engagement
#
# Aswath's engagement with social media platforms, particularly Instagram, is evident through the mention of SunNXT in an Instagram post. This indicates his active participation in digital conversations and suggests a modern approach to communication and information sharing [Data: Entities (32, 33); Relationships (17)].
#
# ## Personal Conversations and Future Planning
#
# In a more personal context, Aswath is involved in dialogues with individuals like Vinu Rakav, discussing future plans and college life. This indicates that he is at a stage where education and career planning are significant, reflecting a forward-thinking mindset and a focus on personal development [Data: Entities (20)].

# %% [markdown]
# #### Summary under consideration
# Diversification through Transportation: Burlington Northern Santa Fe
#
# The acquisition of Burlington Northern Santa Fe in 2010 represents Berkshire Hathaway's strategic diversification into the transportation sector. As the largest railroad in the United States, this acquisition has strengthened the conglomerate's presence in the transportation industry and provided a stable revenue stream [Data: Entities (57); Relationships (55)]. This move aligns with Buffett's strategy of investing in essential infrastructure that supports economic growth.

# %%
idx = 57
print(f"Entity : {entity_df.iloc[idx]["title"]}    Type : {entity_df.iloc[idx]["type"]}")
print(f"Description : {entity_df.iloc[idx]["description"]}")
# Out:
# Entity : AKSHAY    Type : PERSON
# Description : Akshay is a person mentioned as potentially accompanying Vinu Rakav in Bangalore

# %%
idx = 5
print(f"Source : {relationships_df.iloc[idx]["source"]}    Target : {relationships_df.iloc[idx]["target"]}    Weight : {relationships_df.iloc[idx]["weight"]}")
print(f"Description : {relationships_df.iloc[idx]["description"]}")
# Out:
# Source : AJITH KUMAR    Target : CHENNAI    Weight : 1.0
# Description : Ajith Kumar was mobbed at the Chennai airport

# %% [markdown]
# #### Summary under consideration
#
# Significant Acquisitions: GEICO and General Re
#
# GEICO and General Re are two significant acquisitions by Berkshire Hathaway that highlight its strategic focus on the insurance sector. GEICO, acquired in 1996, has become a major contributor to the conglomerate's portfolio, reflecting its importance and value [Data: Entities (35); Relationships (48)]. General Re, acquired in 1998 for $22 billion, marked the largest transaction in Berkshire Hathaway's history, underscoring the company's commitment to expanding its insurance operations [Data: Entities (45); Relationships (49)].

# %%
idx = 45
print(f"Entity : {entity_df.iloc[idx]["title"]}    Type : {entity_df.iloc[idx]["type"]}")
print(f"Description : {entity_df.iloc[idx]["description"]}")
# Out:
# Entity : GENERAL RE    Type : ORGANIZATION
# Description : General Re is a prominent reinsurer that was acquired by Berkshire Hathaway in 1998. This acquisition was a significant milestone, as it marked the largest transaction in Berkshire Hathaway's history, with a deal valued at $22 billion.

# %%
idx = 49
print(f"Source : {relationships_df.iloc[idx]["source"]}    Target : {relationships_df.iloc[idx]["target"]}    Weight : {relationships_df.iloc[idx]["weight"]}")
print(f"Description : {relationships_df.iloc[idx]["description"]}")
# Out:
# Source : WARREN BUFFETT    Target : GENERAL RE    Weight : 8.0
# Description : Warren Buffett acquired General Re in 1998 for $22 billion

# %% [markdown]
# ### Visualize Graph

# %%
G = nx.DiGraph()

# %%
for _, row in entity_df.iterrows():
    G.add_node(row['title'], type=row['type'], description=row['description'])

# %%
for _, row in relationships_df.iterrows():
    G.add_edge(row['source'], row['target'], description=row['description'], strength=row['weight'])

# %%
plt.figure(figsize=(25, 25))
pos = nx.spring_layout(G, k=0.5)

node_colors = ['lightblue' if G.nodes[n]['type'] == 'user' else 'lightgreen' for n in G.nodes]
nx.draw_networkx_nodes(G, pos, node_size=500, node_color=node_colors)

nx.draw_networkx_edges(G, pos, arrowstyle='->', arrowsize=10)

nx.draw_networkx_labels(G, pos, font_size=12)

edge_labels = {(u, v): d['strength'] for u, v, d in G.edges(data=True)}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')

plt.title("Knowledge Graph Visualization")
plt.axis('off')
plt.tight_layout()
plt.show()
